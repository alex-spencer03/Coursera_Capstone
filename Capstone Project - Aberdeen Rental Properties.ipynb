# %% [markdown]
# # Does proximity to amenities impacts the rental price for a property in Aberdeen?

# %% [markdown]
# ## Table of Contents
#
# <div>
#
# 1. [A description of the problem and a discussion of the background](#0)<br>
# 2. [Data sources](#1)<br>
# 3. [Data scraping and handling null values](#2)<br>
# 4. [Data Analysis](#3)<br>
# 5. [Downloading and analysing the FourSquare data against rental properties](#4)<br>
# 6. [Conclusion](#5)<br>
#
# </div>

# %% [markdown]
# ## A description of the problem and a discussion of the background.<a id="0"></a>

# %% [markdown]
# **Introduction/ Business Problem**
#
# I have been renting in Aberdeen, Scotland for nearly 9 years and one thing I could never fully comprehend was the rental price. I would find 2 properties in close proximity to each other, and which to me seemed to be fairly similar, but with very different asking prices.
#
# It got me thinking: 'What actually determines the rental price for a property in Aberdeen?'. Is it the location? Maybe the square footage or EPC band? What about it's proximity to amenities such as shops, cafes and restaurants? There is surprisingly less data publicly available on this matter than compared to that accessible to home buyers.
#
# As part of the IBM Data Science Professional Certificate, this project required the use of FourSquare data. The analysis therefore looks at the relationship between the rental prices of properties in Aberdeen and their proximity to amenities clusters.
#
# **Target audience**
#
# The conclusions of this mini-research are meant to give my fellow renters some insight into rental prices in Aberdeen and what most impacts them. This in turn is meant to aid them into deciding on what to focus in their searches.

# %% [markdown]
# ## Data sources<a id="1"></a>

# %% [markdown]
# The below data sources used for analysis have also been made available on my Github repository:
# https://github.com/alex-spencer03/Coursera_Capstone.
#
# 1.	Data of rental properties available for rent: This was scraped from the Aberdeen Solicitors Property Centre’s (ASPC) website on the 15th July 2020: https://www.aspc.co.uk/.
# 2. Venue data from FourSquare's API
#
# A full explanation of each dataset and features can be found in the final report available via the above GitHub link.

# %% [markdown]
# ## Data scraping and handling null values<a id="2"></a>

# %%
# Importing required libraries

import pandas as pd
from pandas.io.json import json_normalize
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import numpy as np
import json
import io
import requests	 # library to handle requests
import re  #very useful for defining search patterns

# Matplotlib and associated plotting modules
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.cm as cm
import matplotlib.colors as colors
# %matplotlib inline


from sklearn.cluster import KMeans

#!pip install geopy
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

#!pip install folium
import folium # map rendering library

print('Libraries imported.')
# Out:
# Libraries imported.

# %%
url = 'https://www.aspc.co.uk/search/?PrimaryPropertyType=Rent&SortBy=PublishedDesc&LastUpdated=AddedAnytime&SearchTerm=&PropertyType=Residential&PriceMin=&PriceMax=&Bathrooms=&OrMoreBathrooms=true&Bedrooms=&OrMoreBedrooms=true&HasCentralHeating=false&HasGarage=false&HasDoubleGarage=false&HasGarden=false&IsNewBuild=false&IsDevelopment=false&IsParkingAvailable=false&IsPartExchangeConsidered=false&PublicRooms=&OrMorePublicRooms=true&IsHmoLicense=false&IsAllowPets=false&IsAllowSmoking=false&IsFullyFurnished=false&IsPartFurnished=false&IsUnfurnished=false&ExcludeUnderOffer=false&IncludeClosedProperties=true&ClosedDatesSearch=14&MapSearchType=EDITED&ResultView=LIST&ResultMode=NONE&AreaZoom=13&AreaCenter[lat]=57.14955426557916&AreaCenter[lng]=-2.0927401123046785&EditedZoom=13&EditedCenter[lat]=57.14955426557916&EditedCenter[lng]=-2.0927401123046785'
api_url = 'https://api.aspc.co.uk/Property/GetProperties?{}&Sort=PublishedDesc&Page=1&PageSize=639'

params = url.split('?')[-1]
data = requests.get(api_url.format(params)).json()

#print(json.dumps(data, indent=4))

# %%
# creating the initial pandas dataframe
column_names=['First_line','Second_line','City','Postcode','Bedrooms','Bathrooms','Lounges','Price','Square_ft','Property_type','Description','Coordinates']
properties = pd.DataFrame(columns=column_names)
properties
# Out:
# Empty DataFrame
# Columns: [First_line, Second_line, City, Postcode, Bedrooms, Bathrooms, Lounges, Price, Square_ft, Property_type, Description, Coordinates]
# Index: []

# %%
# pulling the required info for each column
for property_ in data:
    first_line=property_['Location']['AddressLine1']
    second_line=property_['Location']['LineTwoLocation']
    city=property_['Location']['City']
    postcode=property_['Location']['Postcode']
    bedrooms=property_['Bedrooms']
    bathrooms=property_['Bathrooms']
    lounges=property_['PublicRooms']
    price=property_['Price']
    square_ft=property_['FloorArea']
    property_type=property_['PropertyIconKey']
    description=property_['CategorisationDescription']
    coordinates=property_['Location']['Spatial']['Geography']['WellKnownText']
    
# amending the existing dataframe with required info
    properties=properties.append({'First_line': first_line,
                                 'Second_line':second_line,
                                 'City': city,
                                 'Postcode': postcode,
                                 'Bedrooms': bedrooms,
                                 'Bathrooms': bathrooms,
                                 'Lounges': lounges,
                                 'Price': price,
                                 'Square_ft': square_ft,
                                 'Property_type': property_type,
                                 'Description': description,
                                 'Coordinates': coordinates}, ignore_index=True)

properties.head()
# Out:
#                  First_line                      Second_line       City  \
# 0         3 Ardarroch Close               Aberdeen, AB24 5QG   Aberdeen
# 1           5 Granton Place               Aberdeen, AB10 6QX   Aberdeen
# 2  653b Great Northern Road               Aberdeen, AB24 2BX   Aberdeen
# 3          66 Ashgrove Road               Aberdeen, AB25 3AD   Aberdeen
# 4       4 Ardmurdo Cottages  Keith Hall, Inverurie, AB51 0LS  Inverurie
#
#    Postcode Bedrooms Bathrooms Lounges  Price  Square_ft        Property_type  \
# 0  AB24 5QG        2         1       1  525.0       65.0                 FLAT
# 1  AB10 6QX        1         1       1  395.0       30.0                 FLAT
# 2  AB24 2BX        2         1       1  525.0       47.0                 FLAT
# 3  AB25 3AD        2         1       1  495.0       53.0                 FLAT
# 4  AB51 0LS        3         1       1  595.0       74.0  HOUSE_SEMI_DETACHED
#
#                                          Description  \
# 0  Fully furnished 2 Bdrm 1st flr Flat. Hall. Lou...
# 1  Fully furnished 1 Bdrm Top flr Flat. Hall. Lou...
# 2  Fully furnished 2 Bdrm 2nd flr Flat. Hall. Lou...
# 3  Fully furnished 2 Bdrm 1st flr Flat. Hall. Lou...
# 4  Unfurnished 3 Bdrm Semi-detached Cottage. Grou...
#
#                             Coordinates
# 0           POINT (-2.091734 57.159231)
# 1           POINT (-2.119444 57.139894)
# 2          POINT (-2.136356 57.1723365)
# 3  POINT (-2.11906680000004 57.1587937)
# 4          POINT (-2.3559582 57.262144)

# %%
properties.shape
# Out:
# (512, 12)

# %% [markdown]
# ### Data cleaning and handling null values

# %%
import re  #very useful for defining search patterns

# creating the Council tax, EPC band, Garden and Parking columns by extracting the data from the Description column
# note to self: (?i) case insensitive modifier

properties['Council_tax_band'] = properties['Description'].str.extract(r'(?i)\(((?:CT)[^()*&?%]+)\)', expand=False)
properties['EPC_band'] = properties['Description'].str.extract(r'(?i)\(((?:EPC)[^()*&?%]+)\)', expand=False)
properties['Garden']= properties.Description.str.extract(r'\b(Garden)\b', expand=False)
properties['Parking']= properties.Description.str.extract(r'\b(Parking)\b', expand=False)

#sorting out the latitude and longitude of the properties
properties['Coordinates']=properties.Coordinates.str.strip('POINT (')
properties['Coordinates']=properties.Coordinates.str.strip(')')
properties['Longitude'], properties['Latitude']= properties['Coordinates'].str.split(' ',1).str

#dropping columns no longer required
properties.drop(['Description'], axis=1, inplace=True)
properties.drop(['Second_line'], axis=1, inplace=True)
properties.drop(['Coordinates'], axis=1, inplace=True)

properties.head()
# Out:
# <ipython-input-6-711ee248097e>:14: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   properties['Longitude'], properties['Latitude']= properties['Coordinates'].str.split(' ',1).str
#                  First_line       City  Postcode Bedrooms Bathrooms Lounges  \
# 0         3 Ardarroch Close   Aberdeen  AB24 5QG        2         1       1
# 1           5 Granton Place   Aberdeen  AB10 6QX        1         1       1
# 2  653b Great Northern Road   Aberdeen  AB24 2BX        2         1       1
# 3          66 Ashgrove Road   Aberdeen  AB25 3AD        2         1       1
# 4       4 Ardmurdo Cottages  Inverurie  AB51 0LS        3         1       1
#
#    Price  Square_ft        Property_type Council_tax_band      EPC_band  \
# 0  525.0       65.0                 FLAT      CT band - C  EPC band - C
# 1  395.0       30.0                 FLAT      CT band - A  EPC band - F
# 2  525.0       47.0                 FLAT      CT Band - C  EPC band - C
# 3  495.0       53.0                 FLAT      CT band - B  EPC band - D
# 4  595.0       74.0  HOUSE_SEMI_DETACHED      CT Band - C  EPC band - F
#
#    Garden  Parking          Longitude    Latitude
# 0     NaN  Parking          -2.091734   57.159231
# 1  Garden      NaN          -2.119444   57.139894
# 2     NaN  Parking          -2.136356  57.1723365
# 3     NaN  Parking  -2.11906680000004  57.1587937
# 4  Garden  Parking         -2.3559582   57.262144

# %%
properties['Council_tax_band'].value_counts()
# Out:
# CT band - A      70
# CT band - B      55
# CT band - C      53
# CT band - D      52
# CT Band - D      43
# CT band - TBC    39
# CT Band - A      35
# CT Band - B      32
# CT Band - C      28
# CT band - E      24
# CT Band - E      19
# CT Band - TBC    16
# CT band - F      14
# CT band - G       7
# CT Band - G       6
# CT Band - F       4
# CT Band - H       2
# CT band - H       2
# CT band -E        1
# CT band -F        1
# CT band B         1
# CT band -B        1
# CT band A         1
# CT - Band D       1
# CT band -TBC      1
# Ct band - D       1
# Name: Council_tax_band, dtype: int64

# %% [markdown]
# ### Because the `Council_tax_band` strings pulled from ASPC's API are not consistent further work is required on them.

# %%
#striping down council tax data
properties['Council_tax_band']=properties.Council_tax_band.str.rstrip()
properties['Council_tax_band']=properties.Council_tax_band.str.replace('band', 'Band')
properties['Council_tax_band']=properties.Council_tax_band.str.replace('CT - Band TBC','CT Band - TBC')
properties['Council_tax_band']=properties.Council_tax_band.str.replace('CT BandTBC','CT Band - TBC')
properties['Council_tax_band']=properties.Council_tax_band.str.replace('CT Band -E','CT Band - E')
properties['Council_tax_band']=properties.Council_tax_band.str.replace('CT Band -F','CT Band - F')
properties['Council_tax_band']=properties.Council_tax_band.str.replace(' -','')

properties['EPC_band']=properties.EPC_band.str.replace(' -','')

#making property_type entries more pleasent to view
properties['Property_type']=properties.Property_type.str.replace('FLAT', 'Flat')
properties['Property_type']=properties.Property_type.str.replace('HOUSE_SEMI_DETACHED', 'House Semi Detached')
properties['Property_type']=properties.Property_type.str.replace('HOUSE_DETACHED', 'House Detached')
properties['Property_type']=properties.Property_type.str.replace('HOUSE_TERRACED', 'House Terraced')

properties.head()
# Out:
#                  First_line       City  Postcode Bedrooms Bathrooms Lounges  \
# 0         3 Ardarroch Close   Aberdeen  AB24 5QG        2         1       1
# 1           5 Granton Place   Aberdeen  AB10 6QX        1         1       1
# 2  653b Great Northern Road   Aberdeen  AB24 2BX        2         1       1
# 3          66 Ashgrove Road   Aberdeen  AB25 3AD        2         1       1
# 4       4 Ardmurdo Cottages  Inverurie  AB51 0LS        3         1       1
#
#    Price  Square_ft        Property_type Council_tax_band    EPC_band  Garden  \
# 0  525.0       65.0                 Flat        CT Band C  EPC band C     NaN
# 1  395.0       30.0                 Flat        CT Band A  EPC band F  Garden
# 2  525.0       47.0                 Flat        CT Band C  EPC band C     NaN
# 3  495.0       53.0                 Flat        CT Band B  EPC band D     NaN
# 4  595.0       74.0  House Semi Detached        CT Band C  EPC band F  Garden
#
#    Parking          Longitude    Latitude
# 0  Parking          -2.091734   57.159231
# 1      NaN          -2.119444   57.139894
# 2  Parking          -2.136356  57.1723365
# 3  Parking  -2.11906680000004  57.1587937
# 4  Parking         -2.3559582   57.262144

# %%
#sanity check
properties['Council_tax_band'].value_counts()
# Out:
# CT Band A      106
# CT Band D       96
# CT Band B       88
# CT Band C       81
# CT Band TBC     55
# CT Band E       44
# CT Band F       19
# CT Band G       13
# CT Band H        4
# CT BandTBC       1
# Ct Band D        1
# CT BandB         1
# Name: Council_tax_band, dtype: int64

# %% [markdown]
# #### Much better

# %%
aberdeen=properties[properties['City'] == 'Aberdeen'].reset_index(drop=True)
aberdeen.head()
# Out:
#                  First_line      City  Postcode Bedrooms Bathrooms Lounges  \
# 0         3 Ardarroch Close  Aberdeen  AB24 5QG        2         1       1
# 1           5 Granton Place  Aberdeen  AB10 6QX        1         1       1
# 2  653b Great Northern Road  Aberdeen  AB24 2BX        2         1       1
# 3          66 Ashgrove Road  Aberdeen  AB25 3AD        2         1       1
# 4     66 Rowett South Drive  Aberdeen  AB21 9GH        2         1       1
#
#    Price  Square_ft Property_type Council_tax_band    EPC_band  Garden  \
# 0  525.0       65.0          Flat        CT Band C  EPC band C     NaN
# 1  395.0       30.0          Flat        CT Band A  EPC band F  Garden
# 2  525.0       47.0          Flat        CT Band C  EPC band C     NaN
# 3  495.0       53.0          Flat        CT Band B  EPC band D     NaN
# 4  590.0       72.0          Flat      CT Band TBC  EPC band B     NaN
#
#    Parking          Longitude    Latitude
# 0  Parking          -2.091734   57.159231
# 1      NaN          -2.119444   57.139894
# 2  Parking          -2.136356  57.1723365
# 3  Parking  -2.11906680000004  57.1587937
# 4  Parking         -2.2019911  57.1817631

# %%
aberdeen_master=aberdeen[aberdeen['City'] == 'Aberdeen'].reset_index(drop=True)
aberdeen_master.shape
# Out:
# (400, 15)

# %% [markdown]
# ### Now that we have a set dataframe we need to investigate and handle any null values which will impact the analysis

# %%
#checking the entire dataframe for null values
aberdeen_master.isnull().sum()
# Out:
# First_line            0
# City                  0
# Postcode              0
# Bedrooms              0
# Bathrooms             0
# Lounges               0
# Price                 0
# Square_ft             0
# Property_type         0
# Council_tax_band      3
# EPC_band              0
# Garden              263
# Parking             173
# Longitude             0
# Latitude              0
# dtype: int64

# %%
#checking which properties do not have a council tax entry
aberdeen_master[aberdeen_master['Council_tax_band'].isnull()]
# Out:
#                   First_line      City  Postcode Bedrooms Bathrooms Lounges  \
# 219  Flat A,  29 Walker Road  Aberdeen  AB11 8DP        1         1       1
# 227        125 Spring Garden  Aberdeen  AB25 1DG        1         1       1
# 317  Flat B,  38 Rose Street  Aberdeen  AB10 1UD        2         1       1
#
#      Price  Square_ft Property_type Council_tax_band    EPC_band  Garden  \
# 219  375.0        0.0          Flat              NaN  EPC band C  Garden
# 227  400.0        0.0          Flat              NaN  EPC band C     NaN
# 317  500.0        0.0          Flat              NaN  EPC band D     NaN
#
#      Parking          Longitude          Latitude
# 219      NaN  -2.08931800000005        57.1363565
# 227  Parking  -2.10179429999994        57.1527173
# 317      NaN  -2.11166270740967  57.1443011521126

# %%
#checking which properties do not have an EPC entry
aberdeen_master[aberdeen_master['EPC_band'].isnull()]
# Out:
# Empty DataFrame
# Columns: [First_line, City, Postcode, Bedrooms, Bathrooms, Lounges, Price, Square_ft, Property_type, Council_tax_band, EPC_band, Garden, Parking, Longitude, Latitude]
# Index: []

# %%
#checking properties with no Square_ft data
aberdeen_master.loc[aberdeen_master['Square_ft'] == 0]
# Out:
#                                      First_line      City  Postcode Bedrooms  \
# 6                       53 Stockethill Crescent  Aberdeen  AB16 5TT        1
# 10                             14 Watson Street  Aberdeen  AB25 2QD        1
# 13                       GFL,  33 Ashvale Place  Aberdeen  AB10 6QD        1
# 17            140 Dee Village,  Millburn Street  Aberdeen  AB11 6SY        3
# 19                    Flat A,  12 Seaton Avenue  Aberdeen  AB24 1XB        2
# 20                  Flat 1,  46 Gilcomston Park  Aberdeen  AB25 1PL        1
# 21                 Flat 31,  44 Gilcomston Park  Aberdeen  AB25 1PL        1
# 22                           48 Deeside Gardens  Aberdeen  AB15 7PN        4
# 23                          92 Bloomfield Court  Aberdeen  AB10 6DT        2
# 25                              18 Frater Place  Aberdeen  AB24 5DG        2
# 26                         7 Merkland Road East  Aberdeen  AB24 5PS        1
# 32                            49 Balmoral Place  Aberdeen  AB10 6HQ        1
# 34                                   22 Denhead  Aberdeen  AB15 9QT        2
# 35                       Flat 5,  4 Queens Gate  Aberdeen  AB15 5XZ        2
# 37                         5 Cairngrassie Drive  Aberdeen  AB12 4TY        1
# 39                             74 Forest Avenue  Aberdeen  AB15 4TL        2
# 41                          44 Esslemont Avenue  Aberdeen  AB25 1SQ        1
# 42                             66 Merkland Lane  Aberdeen  AB24 5RN        2
# 44                               95 Union Grove  Aberdeen  AB10 6SJ        1
# 47                          37 Marischal Street  Aberdeen  AB11 5AD        1
# 50                             58F Baker Street  Aberdeen  AB25 1UT        1
# 55               Flat 3,  10 Bon Accord Terrace  Aberdeen  AB11 6DP        1
# 61                      Flat C,  20 King Street  Aberdeen  AB24 5AX        2
# 62                              122 Union Grove  Aberdeen  AB10 6SB        2
# 64                       17 Kirk Crescent North  Aberdeen  AB15 9RP        4
# 65   Flat 4, Crombie House,  Grandholm Crescent  Aberdeen  AB22 8BD        2
# 66                           104 Headland Court  Aberdeen  AB10 7HW        1
# 69                              279 Union Grove  Aberdeen  AB10 6TB        2
# 74                       3 Kittybrewster Square  Aberdeen  AB25 3DB        2
# 77                            114 Shaw Crescent  Aberdeen  AB25 3BU        2
# 78                            57 Morrison Drive  Aberdeen  AB10 7EA        3
# 79                     2 Strawberry Bank Parade  Aberdeen  AB11 6US        1
# 85                         13b Claremont Street  Aberdeen  AB10 6QP        1
# 86                             294C Union Grove  Aberdeen  AB10 6TP        1
# 87                            72 Stanley Street  Aberdeen  AB10 6UQ        3
# 88                               11a Cairn Road  Aberdeen  AB15 9AL        4
# 91                                11 Ord Street  Aberdeen  AB15 6FT        2
# 92                      Flat B,  43 Queens Road  Aberdeen  AB15 4ZN        2
# 93            150 Dee Village,  Millburn Street  Aberdeen  AB11 6SY        4
# 94                  Flat E,  295 Holburn Street  Aberdeen  AB10 7FN        1
# 96         126F Rubislaw Mansions,  Queens Road  Aberdeen  AB15 8BR        2
# 97                           7 Sunnyside Avenue  Aberdeen  AB24 3LY        3
# 99                    Flat D,  12 Urquhart Road  Aberdeen  AB24 5LL        1
# 102                 Flat E,  2 Frederick Street  Aberdeen  AB24 5HY        2
# 104                                153 Hardgate  Aberdeen  AB11 6XQ        1
# 106       75 Urquhart Court,  105 Urquhart Road  Aberdeen  AB24 5JS        2
# 109                Flat 32,  46 Gilcomston Park  Aberdeen  AB25 1PL        1
# 110                Flat 21,  46 Gilcomston Park  Aberdeen  AB25 1PL        2
# 111                Flat 12,  10 Whitehall Place  Aberdeen  AB25 2NX        1
# 116                    Flat 2,  59 Baker Street  Aberdeen  AB25 1US        1
# 118                            24 Carlton Place  Aberdeen  AB15 4BQ        6
# 121                             23E Fraser Road  Aberdeen  AB25 3UE        2
# 122                           91 May Baird Wynd  Aberdeen  AB25 3RQ        2
# 123                            1b Summer Street  Aberdeen  AB24 4EY        5
# 124       Garden Flat Right,  28 Thomson Street  Aberdeen  AB25 2QQ        1
# 125                            9 Colville Place  Aberdeen  AB24 5LY        1
# 132                           77 May Baird Wynd  Aberdeen  AB25 3RQ        2
# 140             Flat 31,  118 Rosemount Viaduct  Aberdeen  AB25 1NX        3
# 141                       Flat D,  91 Eday Road  Aberdeen  AB15 6LH        2
# 143                         52 Urquhart Terrace  Aberdeen  AB24 5NJ        2
# 145  Flat B, Balmoral Mews,  451 Holburn Street  Aberdeen  AB10 7GU        1
# 146           2 Candlemakers Lane,  Loch Street  Aberdeen  AB25 1DF        2
# 149                          12 Scotsmill Court  Aberdeen  AB21 0EP        2
# 151      First Floor Right,  19 Elmbank Terrace  Aberdeen  AB24 3PE        1
# 153                     22 Ruthrieston Crescent  Aberdeen  AB10 7LD        2
# 158                         116 Auchinyell Road  Aberdeen  AB10 7EB        2
# 159          8 Riverside Manor, Riverside Drive  Aberdeen  AB10 7GR        2
# 160                               62 Gairn Road  Aberdeen  AB10 6AP        1
# 161                  Flat 1,  8 Whitehall Place  Aberdeen  AB25 2AB        3
# 164      Flat A, Ashley Court,  205 Union Grove  Aberdeen  AB10 6TE        2
# 165                           78 Broomhill Road  Aberdeen  AB10 6HU        2
# 169                            24 Whinhill Gate  Aberdeen  AB11 7WG        2
# 174                              283 Links Road  Aberdeen  AB24 5EZ        1
# 176                              32 Sedge Place  Aberdeen  AB12 4SX        2
# 179                   Flat B,  21 Craigton Road  Aberdeen  AB15 7US        2
# 184             Flat 11, 53-67,  Whitehall Road  Aberdeen  AB25 2PQ        2
# 190                         24 Thorngrove Place  Aberdeen  AB15 7FJ        2
# 191                         35 Caledonian Place  Aberdeen  AB11 6TR        1
# 193           143 Dee Village,  Millburn Street  Aberdeen  AB11 6SY        2
# 196                               7 Teviot Road  Aberdeen  AB16 6TF        2
# 197                           28 Whitehall Road  Aberdeen  AB25 2PR        2
# 198             Top Floor Left,  6 Bedford Road  Aberdeen  AB24 3LE        1
# 200        First Floor Left,  30 Thomson Street  Aberdeen  AB25 2QQ        1
# 201                               24 Mill Court  Aberdeen  AB24 2UN        2
# 204                     Flat E,  58 Walker Road  Aberdeen  AB11 8BN        1
# 205                         22 Goodhope Gardens  Aberdeen  AB21 9NG        2
# 209                           12 Maberly Street  Aberdeen  AB25 1NB        2
# 211         55 Mary Elmslie Court,  King Street  Aberdeen  AB24 5BS        2
# 212                                   70 Spital  Aberdeen  AB24 3JU        2
# 213                          14 Shapinsay Court  Aberdeen  AB15 6NG        1
# 219                     Flat A,  29 Walker Road  Aberdeen  AB11 8DP        1
# 220     32 Copper Beech Court,  Auchinyell Road  Aberdeen  AB10 7GL        2
# 221                         40 Morningside Road  Aberdeen  AB10 7NT        3
# 226                            60 Urquhart Road  Aberdeen  AB24 5LX        1
# 227                           125 Spring Garden  Aberdeen  AB25 1DG        1
# 229     Flat J, Melville Court,  75 Rose Street  Aberdeen  AB10 1UH        2
# 231            Top Floor Right,  65 Rose Street  Aberdeen  AB10 1UH        1
# 232                  109 Strawberry Bank Parade  Aberdeen  AB11 6UU        2
# 233                          32 Portland Street  Aberdeen  AB11 6LJ        1
# 234                          113 Macaulay Drive  Aberdeen  AB15 8FL        2
# 237             Flat 21,  118 Rosemount Viaduct  Aberdeen  AB25 1NU        3
# 238                Flat F,  51 Marischal Street  Aberdeen  AB11 5AB        1
# 240                             25 Boswell Road  Aberdeen  AB12 4BA        3
# 242      First Floor Right,  25 Hollybank Place  Aberdeen  AB11 6XR        1
# 251                         40 Esslemont Avenue  Aberdeen  AB25 1SP        1
# 252                     Flat D1,  11 Gallowgate  Aberdeen  AB25 1EB        1
# 256                             79 Bedford Road  Aberdeen  AB24 3LN        4
# 257                           238 Victoria Road  Aberdeen  AB11 9NS        1
# 261                    G/R,  10 Margaret Street  Aberdeen  AB10 1TY        2
# 263                            51e Baker Street  Aberdeen  AB25 1US        1
# 268                   26 & A Half,  Bank Street  Aberdeen  AB11 7SX        2
# 273                             54 Roslin Place  Aberdeen  AB24 5BL        2
# 275                           201 George Street  Aberdeen  AB25 1HY        2
# 276                    Flat C,  108 King Street  Aberdeen  AB24 5BB        1
# 277                      10a South Mount Street  Aberdeen  AB25 2TL        1
# 278                           34 Brighton Place  Aberdeen  AB10 6RS        4
# 279                   Flat E,  12 Roslin Street  Aberdeen  AB24 5NX        2
# 280                          68 Donbank Terrace  Aberdeen  AB24 2SD        2
# 283                         Flat H,  31 Adelphi  Aberdeen  AB11 5BL        1
# 288                    Flat E,  2 Ashvale Court  Aberdeen  AB10 6FA        1
# 293                         52 Lord Hay's Grove  Aberdeen  AB24 1WT        2
# 295                         86 Bannermill Place  Aberdeen  AB24 5EE        1
# 296                 Flat B,  2 Cuparstone Court  Aberdeen  AB10 6FB        2
# 297                              6 School Drive  Aberdeen  AB24 1TE        2
# 298            First Floor,  16 Whitehall Place  Aberdeen  AB25 2PA        2
# 303                          11 Margaret Street  Aberdeen  AB10 1UJ        2
# 307                            137e Union Grove  Aberdeen  AB10 6SN        2
# 308                           559 George Street  Aberdeen  AB25 3XX        2
# 311      146 Ocean Apartments,  52-54 Park Road  Aberdeen  AB24 5RZ        2
# 316                 Flat C,  4 Cuparstone Court  Aberdeen  AB10 6FB        1
# 317                     Flat B,  38 Rose Street  Aberdeen  AB10 1UD        2
# 320                 Townhouse,  Stoneywood Brae  Aberdeen  AB21 9DW        3
# 321         2 Bed Traditional,  Stoneywood Brae  Aberdeen  AB21 9FA        2
# 322                     1 Bed,  Stoneywood Brae  Aberdeen  AB21 9FA        1
# 323               Studio Flat,  Stoneywood Brae  Aberdeen  AB21 9FA        1
# 324             2 Bed Concept,  Stoneywood Brae  Aberdeen  AB21 9FA        2
# 325                           99 Garthdee Drive  Aberdeen  AB10 7HT        3
# 331                   Flat E,  113 Menzies Road  Aberdeen  AB11 9AL        2
# 335                           48 Myrtle Terrace  Aberdeen  AB12 4SZ        2
# 336     Flat F, Melville Court,  75 Rose Street  Aberdeen  AB10 1UH        2
# 338                      19 Great Western Place  Aberdeen  AB10 6QN        1
# 341                          34 Whitehall Place  Aberdeen  AB25 2PB        1
# 342                    Flat A,  490 King Street  Aberdeen  AB24 5ST        3
# 345                          165 Headland Court  Aberdeen  AB10 7HZ        2
# 352                              333 Links Road  Aberdeen  AB24 5DJ        2
# 353                           110 Thistle Court  Aberdeen  AB10 1SE        2
# 354                Flat E,  194 Rosemount Place  Aberdeen  AB25 2XQ        2
# 355      Basement Flat,  17 Summerfield Terrace  Aberdeen  AB24 5JB        1
# 358                        16 Bon Accord Square  Aberdeen  AB11 6DJ        2
# 360                          58 Ashgrove Avenue  Aberdeen  AB25 3BQ        2
# 361                           2 Boa Vista Place  Aberdeen  AB24 3JF        2
# 362                           11 Hilton Heights  Aberdeen  AB24 4QE        2
# 363  Flat F, Oldmill Court,  30 Marywell Street  Aberdeen  AB11 6JR        2
# 364                        93c Claremont Street  Aberdeen  AB10 6QR        1
# 367                             27e Fraser Road  Aberdeen  AB25 3UE        2
# 369                          22 Abbotswell Road  Aberdeen  AB12 3AB        3
# 370                            10F Berry Street  Aberdeen  AB25 1DL        1
# 377                          125 Anderson Drive  Aberdeen  AB15 6BG        4
# 378                          Flat B,  10 Spital  Aberdeen  AB24 3HS        1
# 381                     Flat 5,  89 Queens Road  Aberdeen  AB15 4YS        2
# 382                       80 Hutcheon Low Place  Aberdeen  AB21 9WL        1
# 383                             33 Menzies Road  Aberdeen  AB11 9AU        1
# 384                            19 Picardy Court  Aberdeen  AB10 1UG        1
# 386                            83 Spring Garden  Aberdeen  AB25 1DG        1
# 387                     Flat D,  2 Cottage Brae  Aberdeen  AB10 6DG        1
# 388                   Flat A,  51 Ashvale Place  Aberdeen  AB10 6QJ        1
# 389                   Flat D,  160 Crown Street  Aberdeen  AB11 6HX        2
# 391                           11 Rosebank Place  Aberdeen  AB11 6XN        3
# 392                           31 Justice Street  Aberdeen  AB11 5HS        2
# 398                      148 Grandholm Crescent  Aberdeen  AB22 8BA        3
#
#     Bathrooms Lounges   Price  Square_ft        Property_type  \
# 6           1       1   395.0        0.0                 Flat
# 10          1       1   450.0        0.0                 Flat
# 13          1       1   395.0        0.0                 Flat
# 17          2       1  1000.0        0.0                 Flat
# 19          1       1   325.0        0.0                 Flat
# 20          1       1   435.0        0.0                 Flat
# 21          1       2   485.0        0.0                 Flat
# 22          1       4  1300.0        0.0       House Detached
# 23          1       1   585.0        0.0                 Flat
# 25          1       1   650.0        0.0                 Flat
# 26          1       1   495.0        0.0                 Flat
# 32          1       1   450.0        0.0                 Flat
# 34          2       1   650.0        0.0                 Flat
# 35          1       1   795.0        0.0                 Flat
# 37          1       1   550.0        0.0                 Flat
# 39          1       1   700.0        0.0                 Flat
# 41          1       1   445.0        0.0                 Flat
# 42          2       1   595.0        0.0                 Flat
# 44          1       1   465.0        0.0                 Flat
# 47          1       1   350.0        0.0                 Flat
# 50          1       1   350.0        0.0                 Flat
# 55          1       1   550.0        0.0                 Flat
# 61          1       1   450.0        0.0                 Flat
# 62          1       1   495.0        0.0                 Flat
# 64          2       1  1300.0        0.0  House Semi Detached
# 65          2       1   650.0        0.0                 Flat
# 66          1       1   350.0        0.0                 Flat
# 69          1       1   495.0        0.0                 Flat
# 74          1       1   525.0        0.0                 Flat
# 77          1       1   700.0        0.0                 Flat
# 78          1       1   650.0        0.0                 Flat
# 79          1       1   425.0        0.0                 Flat
# 85          1       1   450.0        0.0                 Flat
# 86          1       1   395.0        0.0                 Flat
# 87          2       2  1100.0        0.0                 Flat
# 88          2       3  1600.0        0.0       House Detached
# 91          1       1   595.0        0.0                 Flat
# 92          1       1   800.0        0.0                 Flat
# 93          2       1  1350.0        0.0                 Flat
# 94          1       1   325.0        0.0                 Flat
# 96          2       1   625.0        0.0                 Flat
# 97          2       1   850.0        0.0       House Terraced
# 99          1       2   450.0        0.0                 Flat
# 102         1       1   495.0        0.0                 Flat
# 104         1       1   350.0        0.0                 Flat
# 106         1       1   625.0        0.0                 Flat
# 109         1       1   395.0        0.0                 Flat
# 110         1       1   525.0        0.0                 Flat
# 111         1       1   475.0        0.0                 Flat
# 116         1       1   425.0        0.0                 Flat
# 118         2       2  2000.0        0.0  House Semi Detached
# 121         1       1   495.0        0.0                 Flat
# 122         1       1   825.0        0.0                 Flat
# 123         2       1  1500.0        0.0                 Flat
# 124         1       1   495.0        0.0                 Flat
# 125         1       1   450.0        0.0                 Flat
# 132         1       1   825.0        0.0                 Flat
# 140         2       1   625.0        0.0                 Flat
# 141         1       1   575.0        0.0                 Flat
# 143         1       1   400.0        0.0                 Flat
# 145         1       1   380.0        0.0                 Flat
# 146         1       1   450.0        0.0                 Flat
# 149         1       1   650.0        0.0                 Flat
# 151         1       1   400.0        0.0                 Flat
# 153         1       1   750.0        0.0                 Flat
# 158         1       1   745.0        0.0  House Semi Detached
# 159         1       1   700.0        0.0                 Flat
# 160         1       1   450.0        0.0                 Flat
# 161         2       1   575.0        0.0                 Flat
# 164         1       1   550.0        0.0                 Flat
# 165         1       1   590.0        0.0                 Flat
# 169         1       1   600.0        0.0                 Flat
# 174         1       1   595.0        0.0                 Flat
# 176         1       1   700.0        0.0  House Semi Detached
# 179         1       1   650.0        0.0                 Flat
# 184         1       1   550.0        0.0                 Flat
# 190         1       1   550.0        0.0                 Flat
# 191         1       1   450.0        0.0                 Flat
# 193         1       1   750.0        0.0                 Flat
# 196         1       1   550.0        0.0       House Terraced
# 197         1       1   800.0        0.0                 Flat
# 198         1       1   450.0        0.0                 Flat
# 200         1       1   495.0        0.0                 Flat
# 201         1       1   475.0        0.0                 Flat
# 204         1       1   350.0        0.0                 Flat
# 205         1       1   700.0        0.0       House Terraced
# 209         1       1   375.0        0.0                 Flat
# 211         1       1   595.0        0.0                 Flat
# 212         1       1   625.0        0.0                 Flat
# 213         1       1   400.0        0.0                 Flat
# 219         1       1   375.0        0.0                 Flat
# 220         1       1   550.0        0.0                 Flat
# 221         2       2   995.0        0.0  House Semi Detached
# 226         1       1   400.0        0.0                 Flat
# 227         1       1   400.0        0.0                 Flat
# 229         2       1   575.0        0.0                 Flat
# 231         1       1   425.0        0.0                 Flat
# 232         1       1   550.0        0.0                 Flat
# 233         1       1   425.0        0.0                 Flat
# 234         1       1   550.0        0.0                 Flat
# 237         2       1   625.0        0.0                 Flat
# 238         1       1   390.0        0.0                 Flat
# 240         1       1   795.0        0.0       House Detached
# 242         1       1   450.0        0.0                 Flat
# 251         1       1   375.0        0.0                 Flat
# 252         1       1   450.0        0.0                 Flat
# 256         1       1   960.0        0.0  House Semi Detached
# 257         1       1   400.0        0.0                 Flat
# 261         1       1   450.0        0.0                 Flat
# 263         1       1   350.0        0.0                 Flat
# 268         1       1   700.0        0.0       House Detached
# 273         1       1   550.0        0.0                 Flat
# 275         1       1   450.0        0.0                 Flat
# 276         1       1   450.0        0.0                 Flat
# 277         1       1   475.0        0.0                 Flat
# 278         2       3  1800.0        0.0       House Terraced
# 279         1       1   480.0        0.0                 Flat
# 280         1       1   650.0        0.0  House Semi Detached
# 283         1       1   450.0        0.0                 Flat
# 288         1       1   375.0        0.0                 Flat
# 293         2       1   575.0        0.0                 Flat
# 295         1       1   525.0        0.0                 Flat
# 296         1       1   500.0        0.0                 Flat
# 297         1       1   400.0        0.0                 Flat
# 298         1       1   625.0        0.0                 Flat
# 303         1       1   525.0        0.0                 Flat
# 307         2       1   625.0        0.0                 Flat
# 308         1       1   450.0        0.0                 Flat
# 311         2       1   795.0        0.0                 Flat
# 316         1       1   450.0        0.0                 Flat
# 317         1       1   500.0        0.0                 Flat
# 320         2       1  1431.0        0.0       House Terraced
# 321         2       1   754.0        0.0                 Flat
# 322         1       1   741.0        0.0                 Flat
# 323         1       1   529.0        0.0                 Flat
# 324         2       1   770.0        0.0                 Flat
# 325         1       1   600.0        0.0                 Flat
# 331         1       1   475.0        0.0                 Flat
# 335         1       1   700.0        0.0  House Semi Detached
# 336         1       1   595.0        0.0                 Flat
# 338         1       1   450.0        0.0                 Flat
# 341         1       1   495.0        0.0                 Flat
# 342         1       0   675.0        0.0                 Flat
# 345         1       1   500.0        0.0                 Flat
# 352         1       1   650.0        0.0                 Flat
# 353         1       1   525.0        0.0                 Flat
# 354         1       1   695.0        0.0                 Flat
# 355         1       1   375.0        0.0                 Flat
# 358         1       1   825.0        0.0                 Flat
# 360         1       1   550.0        0.0                 Flat
# 361         1       1   475.0        0.0                 Flat
# 362         1       1   950.0        0.0                 Flat
# 363         1       1   600.0        0.0                 Flat
# 364         1       1   450.0        0.0                 Flat
# 367         1       1   580.0        0.0                 Flat
# 369         1       1   695.0        0.0                 Flat
# 370         1       1   470.0        0.0                 Flat
# 377         2       4  1500.0        0.0       House Detached
# 378         1       1   400.0        0.0                 Flat
# 381         1       1   690.0        0.0                 Flat
# 382         1       1   450.0        0.0                 Flat
# 383         1       1   395.0        0.0                 Flat
# 384         1       1   450.0        0.0                 Flat
# 386         1       1   450.0        0.0                 Flat
# 387         1       1   375.0        0.0                 Flat
# 388         1       1   475.0        0.0                 Flat
# 389         1       1   475.0        0.0                 Flat
# 391         1       1   450.0        0.0                 Flat
# 392         1       1   500.0        0.0                 Flat
# 398         2       1  1000.0        0.0                 Flat
#
#     Council_tax_band    EPC_band  Garden  Parking          Longitude  \
# 6          CT Band A  EPC band C     NaN  Parking  -2.14537919999998
# 10         CT Band C  EPC band E     NaN      NaN         -2.1176865
# 13       CT Band TBC  EPC band F  Garden      NaN         -2.1154094
# 17         CT Band E  EPC band C     NaN  Parking  -2.09905209999999
# 19         CT Band B  EPC band E     NaN      NaN  -2.09346059999996
# 20       CT Band TBC  EPC band E     NaN      NaN  -2.10928947422238
# 21       CT Band TBC  EPC band F     NaN      NaN  -2.10901773862304
# 22         CT Band F  EPC band D  Garden  Parking          -2.145494
# 23         CT Band D  EPC band C     NaN  Parking          -2.112903
# 25       CT Band TBC  EPC band C     NaN  Parking         -2.0858692
# 26         CT Band A  EPC band C     NaN      NaN         -2.0942394
# 32         CT Band B  EPC band C     NaN      NaN  -2.11947980000002
# 34       CT Band TBC  EPC band C     NaN  Parking  -2.17799109999999
# 35       CT Band TBC  EPC band E     NaN  Parking           -2.13281
# 37         CT Band A  EPC band E  Garden  Parking  -2.14264370000001
# 39         CT Band D  EPC band C  Garden      NaN         -2.1295278
# 41         CT Band C  EPC band D  Garden      NaN  -2.11542250000002
# 42         CT Band D  EPC band B     NaN  Parking  -2.09033799999997
# 44       CT Band TBC  EPC band D  Garden      NaN         -2.1171186
# 47         CT Band A  EPC band D     NaN  Parking  -2.09276209999996
# 50         CT Band A  EPC band D     NaN      NaN           -2.11022
# 55       CT Band TBC  EPC band C     NaN      NaN         -2.1088139
# 61       CT Band TBC  EPC band E     NaN      NaN  -2.09319015396727
# 62        CT BandTBC  EPC band E     NaN      NaN  -2.11886530793459
# 64       CT Band TBC  EPC band D  Garden  Parking         -2.1812089
# 65         CT Band D  EPC band C     NaN  Parking  -2.12333420000004
# 66         CT Band A  EPC band D     NaN  Parking  -2.12516489999996
# 69       CT Band TBC  EPC band D     NaN      NaN  -2.12714848095095
# 74         CT Band D  EPC band C     NaN  Parking         -2.1166012
# 77         CT Band D  EPC band B     NaN  Parking         -2.1234934
# 78         CT Band C  EPC band C     NaN      NaN  -2.14101256665651
# 79         CT Band C  EPC band C     NaN  Parking  -2.10871670000006
# 85         CT Band A  EPC band D     NaN      NaN  -2.11820230000001
# 86         CT Band A  EPC band D     NaN      NaN         -2.1291575
# 87         CT Band E  EPC band D  Garden      NaN         -2.1232057
# 88         CT Band G  EPC band C  Garden  Parking  -2.19390928570557
# 91         CT Band D  EPC band D  Garden  Parking  -2.15305309999997
# 92         CT Band E  EPC band D     NaN      NaN  -2.13463517724608
# 93         CT Band E  EPC band B     NaN  Parking  -2.09965169999998
# 94         CT Band A  EPC band D  Garden      NaN  -2.11479529999997
# 96         CT Band E  EPC band D     NaN  Parking  -2.14609819999998
# 97         CT Band D  EPC band C  Garden      NaN  -2.10787189999996
# 99       CT Band TBC  EPC band C     NaN      NaN  -2.09384933862306
# 102      CT Band TBC  EPC band D  Garden  Parking  -2.09359069204298
# 104      CT Band TBC  EPC band C     NaN      NaN         -2.1116313
# 106      CT Band TBC  EPC band B     NaN  Parking         -2.0859974
# 109      CT Band TBC  EPC band E     NaN      NaN         -2.1093572
# 110        CT Band A  EPC band E     NaN      NaN  -2.10927136931153
# 111      CT Band TBC  EPC band D     NaN      NaN  -2.11563168465577
# 116      CT Band TBC  EPC band D     NaN      NaN  -2.10997766931152
# 118        CT Band G  EPC band F  Garden      NaN  -2.13182449999999
# 121        CT Band D  EPC band B     NaN  Parking          -2.109576
# 122        CT Band E  EPC band B     NaN  Parking         -2.1168007
# 123      CT Band TBC  EPC band B     NaN  Parking         -2.1249352
# 124        CT Band C  EPC band C     NaN  Parking         -2.1199057
# 125      CT Band TBC  EPC band D     NaN      NaN         -2.0926687
# 132        CT Band E  EPC band B     NaN  Parking         -2.1168007
# 140      CT Band TBC  EPC band C     NaN      NaN         -2.1101266
# 141      CT Band TBC  EPC band C     NaN  Parking  -2.16858230000003
# 143        CT Band C  EPC band C     NaN  Parking         -2.0868685
# 145        CT Band C  EPC band C  Garden  Parking  -2.11659059444276
# 146        CT Band D  EPC band D     NaN  Parking  -2.09949819999997
# 149      CT Band TBC  EPC band C     NaN  Parking  -2.28463579999993
# 151        CT Band A  EPC band C     NaN      NaN  -2.10760570000002
# 153        CT Band D  EPC band D  Garden      NaN  -2.12271740000006
# 158        CT Band B  EPC band E  Garden  Parking  -2.14323460000003
# 159        CT Band D  EPC band C     NaN      NaN          -2.117787
# 160        CT Band C  EPC band D     NaN  Parking  -2.11127850000003
# 161        CT Band D  EPC band D     NaN      NaN  -2.11538072327881
# 164        CT Band D  EPC band D  Garden  Parking  -2.12210270000003
# 165        Ct Band D  EPC band D  Garden      NaN          -2.120582
# 169        CT Band E  EPC band C     NaN  Parking  -2.10602960000006
# 174        CT Band C  EPC band B     NaN  Parking          -2.084413
# 176        CT Band D  EPC band D  Garden  Parking  -2.14090959999999
# 179        CT Band D  EPC band C     NaN  Parking         -2.1392781
# 184        CT Band D  EPC band C     NaN  Parking         -2.1253823
# 190        CT Band E  EPC band C     NaN  Parking         -2.1384372
# 191        CT Band B  EPC band D     NaN      NaN  -2.10514699999999
# 193        CT Band D  EPC band B     NaN  Parking  -2.09905209999999
# 196        CT Band B  EPC band D  Garden  Parking         -2.1683628
# 197      CT Band TBC  EPC band D  Garden      NaN         -2.1237532
# 198      CT Band TBC  EPC band D     NaN      NaN         -2.1117872
# 200        CT Band C  EPC band C  Garden      NaN  -2.11979529999996
# 201        CT Band C  EPC band D  Garden  Parking  -2.13304363862301
# 204        CT Band A  EPC band E     NaN      NaN          -2.090355
# 205        CT Band C  EPC band B     NaN  Parking  -2.16054219286798
# 209        CT Band C  EPC band D     NaN      NaN  -2.10478520000004
# 211      CT Band TBC  EPC band C     NaN  Parking         -2.0923766
# 212        CT Band B  EPC band D     NaN  Parking  -2.09960320000005
# 213        CT Band A  EPC band C     NaN  Parking  -2.17742350000003
# 219              NaN  EPC band C  Garden      NaN  -2.08931800000005
# 220        CT Band C  EPC band B     NaN      NaN         -2.1387717
# 221        CT Band E  EPC band E  Garden      NaN   -2.1357007994751
# 226        CT Band A  EPC band D     NaN      NaN         -2.0904246
# 227              NaN  EPC band C     NaN  Parking  -2.10179429999994
# 229        CT Band D  EPC band D     NaN  Parking  -2.11293209999997
# 231        CT Band A  EPC band D     NaN      NaN          -2.112853
# 232        CT Band D  EPC band C     NaN  Parking         -2.1102123
# 233        CT Band A  EPC band C  Garden      NaN  -2.09873200000004
# 234      CT Band TBC  EPC band C     NaN  Parking  -2.16075948360594
# 237      CT Band TBC  EPC band C     NaN      NaN  -2.11014698374083
# 238      CT Band TBC  EPC band C     NaN      NaN  -2.09187506931152
# 240        CT Band E  EPC band C  Garden  Parking         -2.1461647
# 242        CT Band A  EPC band D  Garden  Parking          -2.112338
# 251      CT Band TBC  EPC band F     NaN      NaN         -2.1151783
# 252      CT Band TBC  EPC band D     NaN      NaN   -2.0978061699376
# 256        CT Band E  EPC band E  Garden  Parking         -2.1086031
# 257        CT Band A  EPC band F     NaN      NaN  -2.07819089999998
# 261        CT Band C  EPC band D  Garden      NaN         -2.1132112
# 263        CT Band B  EPC band E     NaN      NaN         -2.1097921
# 268        CT Band E  EPC band E  Garden      NaN         -2.0988362
# 273        CT Band C  EPC band C     NaN  Parking          -2.087883
# 275      CT Band TBC  EPC band C     NaN      NaN  -2.10227602421629
# 276      CT Band TBC  EPC band D     NaN      NaN  -2.09361215396728
# 277      CT Band TBC  EPC band D     NaN      NaN  -2.11161372516165
# 278        CT Band G  EPC band C  Garden      NaN         -2.1257908
# 279        CT Band B  EPC band D     NaN      NaN  -2.08994480000001
# 280        CT Band C  EPC band B  Garden  Parking  -2.12289729999998
# 283      CT Band TBC  EPC band C     NaN      NaN         -2.0961683
# 288        CT Band B  EPC band C     NaN  Parking  -2.11468860000002
# 293        CT Band D  EPC band C     NaN  Parking          -2.094909
# 295      CT Band TBC  EPC band C     NaN  Parking   -2.0851359232788
# 296      CT Band TBC  EPC band C     NaN      NaN   -2.1147617116394
# 297        CT Band A  EPC band F     NaN      NaN          -2.096143
# 298      CT Band TBC  EPC band C  Garden      NaN         -2.1160877
# 303        CT Band C  EPC band D     NaN      NaN          -2.113264
# 307      CT Band TBC  EPC band B     NaN  Parking  -2.11884969814763
# 308      CT Band TBC  EPC band F     NaN      NaN  -2.10781826931156
# 311      CT Band TBC  EPC band B     NaN  Parking  -2.08595943411561
# 316        CT Band C  EPC band C     NaN  Parking          -2.114869
# 317              NaN  EPC band D     NaN      NaN  -2.11166270740967
# 320        CT Band F  EPC band B  Garden  Parking         -2.1771749
# 321        CT Band D  EPC band B     NaN  Parking          -2.176262
# 322        CT Band B  EPC band B     NaN  Parking          -2.176262
# 323        CT Band A  EPC band B     NaN  Parking         -2.1761333
# 324        CT Band D  EPC band B     NaN  Parking          -2.176262
# 325        CT Band B  EPC band D     NaN      NaN         -2.1329171
# 331        CT Band A  EPC band D     NaN      NaN         -2.0938353
# 335        CT Band D  EPC band D  Garden  Parking         -2.1435221
# 336        CT Band D  EPC band D     NaN      NaN         -2.1129321
# 338        CT Band B  EPC band D     NaN      NaN  -2.11762139999996
# 341        CT Band C  EPC band C     NaN      NaN          -2.117981
# 342        CT Band C  EPC band F  Garden      NaN  -2.09658349999995
# 345      CT Band TBC  EPC band D     NaN  Parking  -2.12503530000004
# 352        CT Band D  EPC band C     NaN  Parking           -2.08361
# 353        CT Band A  EPC band E     NaN      NaN  -2.11335086773682
# 354        CT Band D  EPC band D     NaN      NaN  -2.11834429999999
# 355        CT Band A  EPC band E     NaN      NaN  -2.09339299999999
# 358        CT Band D  EPC band D     NaN      NaN  -2.10719300000005
# 360        CT Band D  EPC band C     NaN  Parking         -2.1195754
# 361        CT Band B  EPC band D  Garden      NaN  -2.10031460000005
# 362        CT Band D  EPC band C     NaN  Parking  -2.13025370000003
# 363        CT Band D  EPC band C     NaN      NaN  -2.10059899999999
# 364        CT Band A  EPC band D  Garden      NaN  -2.12102809999999
# 367        CT Band C  EPC band C     NaN  Parking         -2.1092632
# 369        CT Band C  EPC band D  Garden  Parking         -2.0959378
# 370        CT Band C  EPC band C     NaN  Parking          -2.099149
# 377        CT Band H  EPC band E  Garden  Parking          -2.143854
# 378        CT Band B  EPC band C     NaN      NaN           -2.09911
# 381        CT Band D  EPC band D     NaN  Parking  -2.13988615449215
# 382        CT Band B  EPC band C     NaN  Parking  -2.14551779999999
# 383        CT Band A  EPC band D  Garden      NaN         -2.0898621
# 384        CT Band C  EPC band C     NaN  Parking          -2.112437
# 386        CT Band B  EPC band E     NaN  Parking         -2.1003962
# 387        CT Band A  EPC band E     NaN  Parking          -2.117125
# 388        CT Band A  EPC band D  Garden      NaN  -2.11699900992585
# 389        CT Band C  EPC band D     NaN      NaN  -2.10102059999997
# 391        CT Band C  EPC band D  Garden  Parking          -2.110026
# 392        CT Band A  EPC band D     NaN      NaN  -2.09140290000005
# 398        CT Band D  EPC band E     NaN  Parking         -2.1235752
#
#              Latitude
# 6          57.1564108
# 10         57.1504003
# 13         57.1407372
# 17         57.1388515
# 19         57.1678847
# 20   57.1489237613353
# 21   57.1490922389754
# 22          57.125404
# 23         57.1355387
# 25         57.1538807
# 26         57.1588147
# 32         57.1353464
# 34   57.1203186091615
# 35         57.1421627
# 37         57.0543684
# 39         57.1375267
# 41         57.1487854
# 42         57.1588245
# 44         57.1411186
# 47         57.1474531
# 50          57.149424
# 55         57.1432838
# 61   57.1487014201249
# 62   57.1411139963873
# 64         57.1195331
# 65         57.1771506
# 66         57.1262878
# 69   57.1388370278512
# 74         57.1604765
# 77         57.1574925
# 78   57.1235048564145
# 79         57.1421908
# 85         57.1398349
# 86         57.1387682
# 87         57.1417339
# 88    57.114704622199
# 91         57.1440366
# 92   57.1412401463347
# 93         57.1388465
# 94         57.1360605
# 96         57.1392971
# 97         57.1621921
# 99   57.1543195710245
# 102  57.1504756358079
# 104        57.1389428
# 106        57.1548755
# 109        57.1489314
# 110   57.148943039867
# 111   57.147994241048
# 116  57.1491264407994
# 118        57.1457652
# 121         57.155264
# 122        57.1565925
# 123        57.1687273
# 124        57.1505039
# 125        57.1547372
# 132        57.1565925
# 140  57.1490041406455
# 141        57.1487914
# 143        57.1552394
# 145  57.1315034587524
# 146         57.151122
# 149        57.2100093
# 151        57.1579406
# 153        57.1280495
# 158        57.1219916
# 159        57.1265297
# 160        57.1332269
# 161  57.1480563802956
# 164        57.1398233
# 165         57.134054
# 169        57.1360185
# 174        57.1527794
# 176         57.057199
# 179        57.1312735
# 184        57.1465623
# 190        57.1331549
# 191        57.1391365
# 193        57.1388515
# 196        57.1566897
# 197        57.1463087
# 198        57.1598845
# 200        57.1506404
# 201  57.1736752391598
# 204         57.136235
# 205  57.1768822813996
# 209        57.1522859
# 211        57.1556923
# 212        57.1592038
# 213        57.1501735
# 219        57.1363565
# 220        57.1242063
# 221  57.1280561878202
# 226        57.1547138
# 227        57.1527173
# 229        57.1463317
# 231         57.145829
# 232        57.1413305
# 233        57.1395886
# 234  57.1337650063232
# 237  57.1490284678729
# 238  57.1467706811046
# 240        57.0600029
# 242         57.139451
# 251        57.1486573
# 252  57.1493809267207
# 256        57.1627885
# 257        57.1365973
# 261         57.145251
# 263        57.1493288
# 268        57.1381626
# 273         57.152981
# 275  57.1505989378926
# 276  57.1505812967945
# 277  57.1501802312754
# 278        57.1368688
# 279        57.1542102
# 280         57.173351
# 283        57.1470099
# 288        57.1408145
# 293         57.172703
# 295   57.151351312977
# 296   57.140411670226
# 297        57.1651133
# 298        57.1477409
# 303        57.1450378
# 307  57.1408427636245
# 308  57.1558352771499
# 311  57.1556495739213
# 316        57.1403651
# 317  57.1443011521126
# 320        57.1846138
# 321        57.1840339
# 322        57.1840339
# 323         57.184244
# 324        57.1840339
# 325         57.123675
# 331        57.1340407
# 335        57.0579473
# 336        57.1463317
# 338        57.1401309
# 341         57.147261
# 342        57.1622188
# 345        57.1270335
# 352         57.153742
# 353  57.1455357362807
# 354        57.1496331
# 355        57.1517151
# 358         57.142895
# 360        57.1599706
# 361        57.1596193
# 362        57.1652816
# 363        57.1423639
# 364         57.138711
# 367        57.1550252
# 369        57.1267042
# 370         57.150422
# 377         57.141288
# 378        57.1576349
# 381  57.1400513178684
# 382        57.1758259
# 383        57.1374212
# 384        57.1446582
# 386        57.1529029
# 387          57.13801
# 388  57.1405024855983
# 389        57.1407203
# 391         57.139723
# 392        57.1489248
# 398        57.1762557

# %%
prop_sqft=pd.DataFrame((aberdeen_master.loc[aberdeen_master['Square_ft'] > 0])).reset_index(drop=True)
prop_sqft[['Price','Square_ft']].corr()
# Out:
#               Price  Square_ft
# Price      1.000000   0.873567
# Square_ft  0.873567   1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sns.regplot(x="Square_ft", y="Price", data=prop_sqft)
plt.ylim(0,)
# Out:
# (0.0, 2610.3811773368734)

# %% [markdown]
# ### Important: this data was initially pulled on 15th July 2020 and the above code was for illustrative purposes only.
#
# Just as can be seen now the number of properties without square footage values is high. To obtain this data would have been very time consuming and I had to deternine if it had any value to bring to justify the time and resources to obtain it.
#
# As can be seen in the above .corr() function there is a 0.851765 correlation between the price and the square footage of the property. The above scatter plot confirms this. Not including this data could have skewed the final results.
#
# The initial properties dataset was persisted to DB2 Warehouse on 15th July 2020 and uploaded to GitHub on 5th August 2020.

# %% [markdown]
# ## Data Analysis<a id="3"></a>

# %%
import pandas as pd
import io

# Downloading csv file from my GitHub account
url2 = "https://raw.githubusercontent.com/alex-spencer03/Coursera_Capstone/master/aberdeen_master.csv"
download = requests.get(url2).content

# Reading doanloded content into pandas dataframe
aberdeen_master = pd.read_csv(io.StringIO(download.decode('utf-8')))

# sanity check
aberdeen_master.head()
# Out:
#                           First_line      City  Postcode  \
# 0                       2 Albert Den  Aberdeen  AB25 1YX
# 1                  3c Anderson Drive  Aberdeen  AB15 4ST
# 2                  11 Cypress Avenue  Aberdeen  AB23 8LA
# 3  First Floor Left,  31 Bank Street  Aberdeen  AB11 7TA
# 4                   66 Ashgrove Road  Aberdeen  AB25 3AD
#
#                   Council_ward  Bedrooms  Bathrooms  Lounges  Price  \
# 0         Midstocket/Rosemount         2          2        1    750
# 1  Airyhall/Broomhill/Garthdee         2          2        1    750
# 2                Bridge of Don         2          1        1    625
# 3              Torry/Ferryhill         1          1        1    475
# 4         Midstocket/Rosemount         2          1        1    550
#
#    Square_ft        Property_type Council_tax_band    EPC_band  Parking  \
# 0         75                 Flat        CT Band E  EPC band C  Parking
# 1         82                 Flat        CT Band E  EPC band C  Parking
# 2         69  House Semi Detached        CT Band C  EPC band C  Parking
# 3         46                 Flat        CT Band B  EPC band C  Parking
# 4         53                 Flat        CT Band B  EPC band D      NaN
#
#    Longitude   Latitude
# 0  -2.117279  57.146122
# 1  -2.134406  57.133631
# 2  -2.100588  57.199485
# 3  -2.100533  57.138016
# 4  -2.119067  57.158794

# %%
#sanity check
print(aberdeen_master.dtypes)
# Out:
# First_line           object
# City                 object
# Postcode             object
# Council_ward         object
# Bedrooms              int64
# Bathrooms             int64
# Lounges               int64
# Price                 int64
# Square_ft             int64
# Property_type        object
# Council_tax_band     object
# EPC_band             object
# Parking              object
# Longitude           float64
# Latitude            float64
# dtype: object

# %%
# Dropping City attribute as all instances have the same city
aberdeen_master.drop(['City'], axis=1, inplace=True)

# %%
aberdeen_master.describe()
# Out:
#          Bedrooms   Bathrooms     Lounges        Price   Square_ft  \
# count  446.000000  446.000000  446.000000   446.000000  446.000000
# mean     1.894619    1.215247    1.065022   639.094170   65.964126
# std      0.834707    0.443014    0.325384   268.684001   32.615962
# min      1.000000    1.000000    0.000000   325.000000   26.000000
# 25%      1.000000    1.000000    1.000000   475.000000   47.000000
# 50%      2.000000    1.000000    1.000000   550.000000   58.000000
# 75%      2.000000    1.000000    1.000000   700.000000   75.000000
# max      6.000000    3.000000    4.000000  2300.000000  330.000000
#
#         Longitude    Latitude
# count  446.000000  446.000000
# mean    -2.117851   57.151481
# std      0.027320    0.016319
# min     -2.263654   57.096120
# 25%     -2.126179   57.140279
# 50%     -2.112189   57.148793
# 75%     -2.100270   57.158662
# max     -2.078191   57.212590

# %% [markdown]
# #### Let's calculate and then visualise the correlation between the numerical variables

# %%
aberdeen_master[['Price','Bedrooms','Bathrooms','Lounges','Square_ft','Parking']].corr()
# Out:
#               Price  Bedrooms  Bathrooms   Lounges  Square_ft
# Price      1.000000  0.791809   0.647835  0.530821   0.785406
# Bedrooms   0.791809  1.000000   0.511176  0.480349   0.728791
# Bathrooms  0.647835  0.511176   1.000000  0.308011   0.601473
# Lounges    0.530821  0.480349   0.308011  1.000000   0.616610
# Square_ft  0.785406  0.728791   0.601473  0.616610   1.000000

# %%
sns.regplot(x='Bedrooms', y='Price', data=aberdeen_master)
plt.ylim(0,)
# Out:
# (0.0, 2398.75)

# %%
sns.regplot(x='Bathrooms', y='Price', data=aberdeen_master)
plt.ylim(0,)
# Out:
# (0.0, 2398.75)

# %%
sns.regplot(x='Lounges', y='Price', data=aberdeen_master)
plt.ylim(0,)
# Out:
# (0.0, 2423.2959427351134)

# %%
sns.regplot(x='Square_ft', y='Price', data=aberdeen_master)
plt.ylim(0,)
# Out:
# (0.0, 2893.4353776911375)

# %% [markdown]
# #### Calculating and visualising the correlation between the categorical variables

# %%
ax=sns.boxplot(x="Council_tax_band", y="Price", data=aberdeen_master)
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
# Out:
# [Text(0, 0, 'CT Band E'),
#  Text(1, 0, 'CT Band C'),
#  Text(2, 0, 'CT Band B'),
#  Text(3, 0, 'CT Band F'),
#  Text(4, 0, 'CT Band D'),
#  Text(5, 0, 'CT Band A'),
#  Text(6, 0, 'CT Band H'),
#  Text(7, 0, 'CT Band G')]

# %%
ax=sns.boxplot(x="EPC_band", y="Price", data=aberdeen_master)
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
# Out:
# [Text(0, 0, 'EPC band C'),
#  Text(1, 0, 'EPC band D'),
#  Text(2, 0, 'EPC band B'),
#  Text(3, 0, 'EPC band E'),
#  Text(4, 0, 'EPC band F'),
#  Text(5, 0, 'EPC band G')]

# %%
ax=sns.boxplot(x="Council_ward", y="Price", data=aberdeen_master)
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
# Out:
# [Text(0, 0, 'Midstocket/Rosemount'),
#  Text(1, 0, 'Airyhall/Broomhill/Garthdee'),
#  Text(2, 0, 'Bridge of Don'),
#  Text(3, 0, 'Torry/Ferryhill'),
#  Text(4, 0, 'Lower Deeside'),
#  Text(5, 0, 'Hazlehead/Queens Cross/Countesswells'),
#  Text(6, 0, 'George St/Harbour'),
#  Text(7, 0, 'Kingswells/Sheddocksley/Summerhill'),
#  Text(8, 0, 'Dyce/Bucksburn/Danestone'),
#  Text(9, 0, 'Tillydrone/Seaton/Old Aberdeen'),
#  Text(10, 0, 'Hilton/Woodside/Stockethill'),
#  Text(11, 0, 'Northfield/Mastrick North'),
#  Text(12, 0, 'Kincorth/Nigg/Cove')]

# %%
#applying one-hot encoding to the categorical variables for further analysis
for column in ['Property_type','Council_tax_band','EPC_band','Parking']:
    dummies = pd.get_dummies(aberdeen_master[column])
    aberdeen_master[dummies.columns] = dummies

# %%
aberdeen_master[['Price','CT Band A', 'CT Band B', 'CT Band C', 'CT Band D', 'CT Band E', 'CT Band F', 'CT Band G', 'CT Band H']].corr()
# Out:
#               Price  CT Band A  CT Band B  CT Band C  CT Band D  CT Band E  \
# Price      1.000000  -0.375616  -0.195710  -0.093564   0.078062   0.243886
# CT Band A -0.375616   1.000000  -0.263328  -0.231483  -0.273790  -0.178663
# CT Band B -0.195710  -0.263328   1.000000  -0.241115  -0.285182  -0.186097
# CT Band C -0.093564  -0.231483  -0.241115   1.000000  -0.250694  -0.163592
# CT Band D  0.078062  -0.273790  -0.285182  -0.250694   1.000000  -0.193490
# CT Band E  0.243886  -0.178663  -0.186097  -0.163592  -0.193490   1.000000
# CT Band F  0.450128  -0.117244  -0.122122  -0.107354  -0.126974  -0.082857
# CT Band G  0.345527  -0.053538  -0.055766  -0.049022  -0.057981  -0.037836
# CT Band H  0.315320  -0.033746  -0.035150  -0.030899  -0.036546  -0.023848
#
#            CT Band F  CT Band G  CT Band H
# Price       0.450128   0.345527   0.315320
# CT Band A  -0.117244  -0.053538  -0.033746
# CT Band B  -0.122122  -0.055766  -0.035150
# CT Band C  -0.107354  -0.049022  -0.030899
# CT Band D  -0.126974  -0.057981  -0.036546
# CT Band E  -0.082857  -0.037836  -0.023848
# CT Band F   1.000000  -0.024829  -0.015650
# CT Band G  -0.024829   1.000000  -0.007146
# CT Band H  -0.015650  -0.007146   1.000000

# %%
aberdeen_master[['Price','EPC band B','EPC band C','EPC band D','EPC band E','EPC band F','EPC band G']].corr()
# Out:
#                Price  EPC band B  EPC band C  EPC band D  EPC band E  \
# Price       1.000000    0.173624    0.136696   -0.156957   -0.084807
# EPC band B  0.173624    1.000000   -0.270411   -0.216743   -0.114030
# EPC band C  0.136696   -0.270411    1.000000   -0.594887   -0.312976
# EPC band D -0.156957   -0.216743   -0.594887    1.000000   -0.250860
# EPC band E -0.084807   -0.114030   -0.312976   -0.250860    1.000000
# EPC band F -0.064120   -0.062483   -0.171495   -0.137459   -0.072318
# EPC band G -0.052870   -0.025830   -0.070895   -0.056825   -0.029896
#
#             EPC band F  EPC band G
# Price        -0.064120   -0.052870
# EPC band B   -0.062483   -0.025830
# EPC band C   -0.171495   -0.070895
# EPC band D   -0.137459   -0.056825
# EPC band E   -0.072318   -0.029896
# EPC band F    1.000000   -0.016382
# EPC band G   -0.016382    1.000000

# %% [markdown]
# #### Let's investigate a bit more the relationship between the different variables by looking at the average prices

# %%
test_one=aberdeen_master[['Bedrooms','Bathrooms','Lounges','Square_ft','Price']]
ab_avg_price=test_one.groupby(['Bedrooms','Bathrooms','Lounges'], as_index=False).mean()
ab_avg_price['Sq_diff']=ab_avg_price['Square_ft'].diff()
ab_avg_price['Price_diff']=ab_avg_price['Price'].diff()

#ab_avg_price.sort_values(by=['Difference'], inplace=True, ascending=False)
ab_avg_price
# Out:
#     Bedrooms  Bathrooms  Lounges   Square_ft        Price     Sq_diff  \
# 0          1          1        0   32.500000   337.500000         NaN
# 1          1          1        1   45.164384   454.547945   12.664384
# 2          2          1        1   61.182353   581.788235   16.017969
# 3          2          1        2   79.666667   681.666667   18.484314
# 4          2          2        1   80.102041   765.163265    0.435374
# 5          2          2        2   82.000000   895.000000    1.897959
# 6          3          1        0   95.000000   687.500000   13.000000
# 7          3          1        1   79.000000   856.304348  -16.000000
# 8          3          1        2   91.142857   878.571429   12.142857
# 9          3          2        1   99.200000   955.000000    8.057143
# 10         3          2        2  117.200000  1340.000000   18.000000
# 11         3          3        1  124.000000  1233.333333    6.800000
# 12         4          1        1  100.000000   960.000000  -24.000000
# 13         4          1        2  102.500000  1150.000000    2.500000
# 14         4          2        1  114.166667  1235.000000   11.666667
# 15         4          2        2  133.250000  1023.750000   19.083333
# 16         4          2        4  330.000000  1500.000000  196.750000
# 17         4          3        2  153.000000  1600.000000 -177.000000
# 18         5          2        1  101.000000  1500.000000  -52.000000
# 19         5          2        2  178.000000  1750.000000   77.000000
# 20         5          3        3  252.000000  1900.000000   74.000000
# 21         6          2        3  234.000000  1800.000000  -18.000000
#
#     Price_diff
# 0          NaN
# 1   117.047945
# 2   127.240290
# 3    99.878431
# 4    83.496599
# 5   129.836735
# 6  -207.500000
# 7   168.804348
# 8    22.267081
# 9    76.428571
# 10  385.000000
# 11 -106.666667
# 12 -273.333333
# 13  190.000000
# 14   85.000000
# 15 -211.250000
# 16  476.250000
# 17  100.000000
# 18 -100.000000
# 19  250.000000
# 20  150.000000
# 21 -100.000000

# %% [markdown]
# #### Now let's see what the average rental property looks like in each council ward

# %%
test_one=aberdeen_master[['Council_ward','Bedrooms','Bathrooms','Lounges','Square_ft','Price']]
c_ward_avg=test_one.groupby(['Council_ward'], as_index=False).mean()
c_ward_avg.sort_values(by=['Price'], inplace=True, ascending=False)
c_ward_avg
# Out:
#                             Council_ward  Bedrooms  Bathrooms   Lounges  \
# 8                          Lower Deeside  2.800000   1.600000  1.200000
# 7     Kingswells/Sheddocksley/Summerhill  2.750000   1.250000  1.500000
# 0            Airyhall/Broomhill/Garthdee  2.090909   1.272727  1.181818
# 2               Dyce/Bucksburn/Danestone  2.175000   1.350000  1.125000
# 4   Hazlehead/Queens Cross/Countesswells  1.924242   1.303030  1.121212
# 5            Hilton/Woodside/Stockethill  2.238095   1.285714  1.095238
# 1                          Bridge of Don  2.000000   1.166667  1.166667
# 9                   Midstocket/Rosemount  1.757576   1.257576  1.090909
# 11        Tillydrone/Seaton/Old Aberdeen  2.047619   1.047619  0.952381
# 3                      George St/Harbour  1.831858   1.123894  1.000000
# 12                       Torry/Ferryhill  1.645570   1.164557  1.012658
# 10             Northfield/Mastrick North  2.000000   1.000000  1.000000
# 6                     Kincorth/Nigg/Cove  1.000000   1.000000  1.000000
#
#      Square_ft       Price
# 8   107.000000  989.000000
# 7    82.250000  762.500000
# 0    71.954545  742.045455
# 2    86.450000  721.550000
# 4    74.878788  708.181818
# 5    72.904762  702.380952
# 1    68.500000  665.000000
# 9    62.575758  643.712121
# 11   63.238095  591.904762
# 3    58.716814  577.292035
# 12   55.050633  567.784810
# 10   73.500000  475.000000
# 6    42.000000  420.000000

# %% [markdown]
# #### Let's cluster the properties and visualise the clusters

# %%
# import k-means from clustering stage
from sklearn.cluster import KMeans

# set number of clusters
kclusters = 3

aberdeen_grouped_clustering = aberdeen_master[['Bedrooms','Bathrooms','Lounges','Square_ft','Price','Latitude','Longitude']]

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(aberdeen_grouped_clustering)

# add clustering labels
aberdeen_grouped_clustering.insert(0, 'Cluster Labels', kmeans.labels_)
aberdeen_grouped_clustering.head()
# Out:
#    Cluster Labels  Bedrooms  Bathrooms  Lounges  Square_ft  Price   Latitude  \
# 0               2         2          2        1         75    750  57.146122
# 1               2         2          2        1         82    750  57.133631
# 2               0         2          1        1         69    625  57.199485
# 3               0         1          1        1         46    475  57.138016
# 4               0         2          1        1         53    550  57.158794
#
#    Longitude
# 0  -2.117279
# 1  -2.134406
# 2  -2.100588
# 3  -2.100533
# 4  -2.119067

# %%
import numpy as np # library to handle data in a vectorized manner

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

#!pip install geopy
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# %%
#!pip install folium

# %%
import folium # map rendering library

print('Libraries imported.')
# Out:
# Libraries imported.

# %%
#adding the council_wards into dataframe
council_w=aberdeen_master[['Council_ward','Latitude']]
aberdeen_grouped_clustering=pd.merge(aberdeen_grouped_clustering, council_w, on='Latitude')

# move neighborhood column to the first column
cols = [aberdeen_grouped_clustering.columns[-1]] + list(aberdeen_grouped_clustering.columns[:-1])
aberdeen_grouped_clustering = aberdeen_grouped_clustering[cols]

aberdeen_grouped_clustering.head()
# Out:
#                   Council_ward  Cluster Labels  Bedrooms  Bathrooms  Lounges  \
# 0         Midstocket/Rosemount               2         2          2        1
# 1  Airyhall/Broomhill/Garthdee               2         2          2        1
# 2                Bridge of Don               0         2          1        1
# 3              Torry/Ferryhill               0         1          1        1
# 4         Midstocket/Rosemount               0         2          1        1
#
#    Square_ft  Price   Latitude  Longitude
# 0         75    750  57.146122  -2.117279
# 1         82    750  57.133631  -2.134406
# 2         69    625  57.199485  -2.100588
# 3         46    475  57.138016  -2.100533
# 4         53    550  57.158794  -2.119067

# %%
#getting the coordinates for Aberdeen city
address = 'Aberdeen, Scotland'

geolocator = Nominatim(user_agent="ab_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Aberdeen, Scotland are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Aberdeen, Scotland are 57.1482429, -2.0928095.

# %%
# creating the map of clusters
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# setting the color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# adding the markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(aberdeen_grouped_clustering['Latitude'], aberdeen_grouped_clustering['Longitude'], aberdeen_grouped_clustering['Council_ward'], aberdeen_grouped_clustering['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_603a6d430d014502982e67ac8d116d0f%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_603a6d430d014502982e67ac8d116d0f%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_603a6d430d014502982e67ac8d116d0f%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_603a6d430d014502982e67ac8d116d0f%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B57.1482429%2C%20-2.0928095%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %% [markdown]
# #### Finally, let's examine each cluster

# %%
#Examining the first cluster of properties
cluster_one=pd.DataFrame(aberdeen_grouped_clustering.loc[aberdeen_grouped_clustering['Cluster Labels'] == 0])
cluster_one.describe()
# Out:
#        Cluster Labels    Bedrooms   Bathrooms    Lounges   Square_ft  \
# count           332.0  332.000000  332.000000  332.00000  332.000000
# mean              0.0    1.521084    1.030120    1.00000   52.448795
# std               0.0    0.518108    0.171177    0.10993   13.372892
# min               0.0    1.000000    1.000000    0.00000   26.000000
# 25%               0.0    1.000000    1.000000    1.00000   43.000000
# 50%               0.0    2.000000    1.000000    1.00000   50.000000
# 75%               0.0    2.000000    1.000000    1.00000   60.000000
# max               0.0    3.000000    2.000000    2.00000  121.000000
#
#             Price    Latitude   Longitude
# count  332.000000  332.000000  332.000000
# mean   504.765060   57.151543   -2.113819
# std     83.356144    0.015918    0.022576
# min    325.000000   57.096701   -2.190493
# 25%    445.000000   57.140361   -2.119906
# 50%    500.000000   57.149014   -2.110062
# 75%    571.250000   57.157350   -2.099129
# max    650.000000   57.212590   -2.078191

# %%
#Examining the second cluster of properties
cluster_two=pd.DataFrame(aberdeen_grouped_clustering.loc[aberdeen_grouped_clustering['Cluster Labels'] == 1])
cluster_two.describe()
# Out:
#        Cluster Labels   Bedrooms  Bathrooms    Lounges   Square_ft  \
# count            22.0  22.000000  22.000000  22.000000   22.000000
# mean              1.0   3.681818   2.045455   1.727273  148.045455
# std               0.0   1.041353   0.575473   0.882735   66.948080
# min               1.0   2.000000   1.000000   1.000000   63.000000
# 25%               1.0   3.000000   2.000000   1.000000   98.250000
# 50%               1.0   3.500000   2.000000   1.500000  143.000000
# 75%               1.0   4.000000   2.000000   2.000000  155.750000
# max               1.0   6.000000   3.000000   4.000000  330.000000
#
#              Price   Latitude  Longitude
# count    22.000000  22.000000  22.000000
# mean   1527.500000  57.144258  -2.133763
# std     262.985379   0.016144   0.025848
# min    1200.000000  57.115645  -2.194117
# 25%    1350.000000  57.134654  -2.143769
# 50%    1500.000000  57.144239  -2.132712
# 75%    1712.500000  57.149096  -2.118246
# max    2300.000000  57.184614  -2.086557

# %%
#Examining the third and final cluster of properties
cluster_three=pd.DataFrame(aberdeen_grouped_clustering.loc[aberdeen_grouped_clustering['Cluster Labels'] == 2])
cluster_three.describe()
# Out:
#        Cluster Labels    Bedrooms   Bathrooms     Lounges   Square_ft  \
# count           126.0  126.000000  126.000000  126.000000  126.000000
# mean              2.0    2.476190    1.547619    1.103175   88.095238
# std               0.0    0.665904    0.530768    0.353935   29.248844
# min               2.0    1.000000    1.000000    0.000000   34.000000
# 25%               2.0    2.000000    1.000000    1.000000   72.000000
# 50%               2.0    2.000000    2.000000    1.000000   82.500000
# 75%               2.0    3.000000    2.000000    1.000000   96.750000
# max               2.0    4.000000    3.000000    2.000000  200.000000
#
#              Price    Latitude   Longitude
# count   126.000000  126.000000  126.000000
# mean    822.309524   57.155867   -2.129234
# std     119.889714    0.019533    0.036663
# min     675.000000   57.096120   -2.263654
# 25%     710.000000   57.142875   -2.138267
# 50%     795.000000   57.151138   -2.123748
# 75%     900.000000   57.165151   -2.102581
# max    1150.000000   57.212590   -2.081247

# %% [markdown]
# ## Downloading and analysing the FourSquare data against rental properties<a id="4"></a>

# %%
CLIENT_ID = 'EXSW1MIZO4ZE4VQQP3ZW0GN3KCNDP5ZEWYIC25EUOTMG5Y24' # your Foursquare ID
CLIENT_SECRET = 'VTQFVGSCC0H5GWDIWSZK3RQRHICOF0JB2MHS4CA5ROTLQOTB' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: EXSW1MIZO4ZE4VQQP3ZW0GN3KCNDP5ZEWYIC25EUOTMG5Y24
# CLIENT_SECRET:VTQFVGSCC0H5GWDIWSZK3RQRHICOF0JB2MHS4CA5ROTLQOTB

# %%
LIMIT = 700 # limit of number of venues returned by Foursquare API
radius = 7000 # define radius
# create URL
url3 = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude, 
    longitude, 
    radius, 
    LIMIT)

url3 # display URL
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=EXSW1MIZO4ZE4VQQP3ZW0GN3KCNDP5ZEWYIC25EUOTMG5Y24&client_secret=VTQFVGSCC0H5GWDIWSZK3RQRHICOF0JB2MHS4CA5ROTLQOTB&v=20180605&ll=57.1482429,-2.0928095&radius=7000&limit=700'

# %%
results = requests.get(url3).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '601981402ef4113be0ba7cb3'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'Aberdeen',
#   'headerFullLocation': 'Aberdeen',
#   'headerLocationGranularity': 'city',
#   'totalResults': 111,
#   'suggestedBounds': {'ne': {'lat': 57.21124296300006,
#     'lng': -1.9768901907487855},
#    'sw': {'lat': 57.08524283699994, 'lng': -2.2087288092512147}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5669d04e498e6356a17d6440',
#        'name': 'BrewDog Castlegate',
#        'location': {'address': '5-9 Union St',
#         'lat': 57.14773069623862,
#         'lng': -2.094548465423609,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 57.14773069623862,
#           'lng': -2.094548465423609}],
#         'distance': 119,
#         'postalCode': 'AB11 5BU',
#         'cc': 'GB',
#         'city': 'Aberdeen',
#         'state': 'Aberdeen City',
#         'country': 'United Kingdom',
#         'formattedAddress': ['5-9 Union St',
#          'Aberdeen',
#          'Aberdeen City',
#          'AB11 5BU',
#          'United Kingdom']},
#        'categories': [{'id': '56aa371ce4b08b9a8d57356c',
#          'name': 'Beer Bar',
#          'pluralName': 'Beer Bars',
#          'shortName': 'Beer Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5669d04e498e6356a17d6440-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cb5e80c9c7ba35de2e98d06',
#        'name': 'BrewDog Aberdeen',
#        'location': {'address': '17 Gallowgate',
#         'lat': 57.14951973350749,
#         'lng': -2.097524648430939,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 57.14951973350749,
#           'lng': -2.097524648430939}],
#         'distance': 318,
#         'postalCode': 'AB25 1EB',
#         'cc': 'GB',
#         'city': 'Aberdeen',
#         'state': 'Aberdeen City',
#         'country': 'United Kingdom',
#         'formattedAddress': ['17 Gallowgate',
#          'Aberdeen',
#          'Aberdeen City',
#          'AB25 1EB',
#          'United Kingdom']},
#        'categories': [{'id': '56aa371ce4b08b9a8d57356c',
#          'name': 'Beer Bar',
#          'pluralName': 'Beer Bars',
#          'shortName': 'Beer Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cb5e80c9c7ba35de2e98d06-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '52b2148211d28c56b617dcfa',
#        'name': 'CASC ABERDEEN',
#        'location': {'address': '7 Stirling St',
#         'lat': 57.14587393785565,
#         'lng': -2.097568076984268,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 57.14587393785565,
#           'lng': -2.097568076984268}],
#         'distance': 390,
#         'postalCode': 'AB11 6ND',
#         'cc': 'GB',
#         'city': 'Aberdeen',
#         'state': 'Aberdeen City',
#         'country': 'United Kingdom',
#         'formattedAddress': ['7 Stirling St',
#          'Aberdeen',
#          'Aberdeen City',
#          'AB11 6ND',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '216697284'}},
#       'referralId': 'e-0-52b2148211d28c56b617dcfa-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b86c9f0f964a520749d31e3',
#        'name': 'Cafe 52',
#        'location': {'address': '52 The Green',
#         'lat': 57.14605326221233,
#         'lng': -2.099169795596569,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 57.14605326221233,
#           'lng': -2.099169795596569}],
#         'distance': 454,
#         'postalCode': 'AB11 6BE',
#         'cc': 'GB',
#         'city': 'Aberdeenshire',
#         'state': 'Aberdeenshire',
#         'country': 'United Kingdom',
#         'formattedAddress': ['52 The Green',
#          'Aberdeenshire',
#          'AB11 6BE',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b86c9f0f964a520749d31e3-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '583186c324fd71430d45928e',
#        'name': 'Revolucion de Cuba',
#        'location': {'address': 'Academy Centre Courtyard',
#         'crossStreet': 'Belmont Street',
#         'lat': 57.14741283091897,
#         'lng': -2.101209107146733,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 57.14741283091897,
#           'lng': -2.101209107146733}],
#         'distance': 515,
#         'postalCode': 'AB10 1LB',
#         'cc': 'GB',
#         'city': 'Aberdeen',
#         'state': 'Aberdeen City',
#         'country': 'United Kingdom',
#         'formattedAddress': ['Academy Centre Courtyard (Belmont Street)',
#          'Aberdeen',
#          'Aberdeen City',
#          'AB10 1LB',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-583186c324fd71430d45928e-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b69be08f964a5203eb12be3',
#        'name': 'Belmont Filmhouse',
#        'location': {'address': '49 Belmont St',
#         'lat': 57.147310262696216,
#         'lng': -2.102200338264293,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 57.147310262696216,
#           'lng': -2.102200338264293}],
#         'distance': 576,
#         'postalCode': 'AB10 1JS',
#         'cc': 'GB',
#         'city': 'Aberdeen',
#         'state': 'Aberdeen City',
#         'country': 'United Kingdom',
#         'formattedAddress': ['49 Belmont St',
#          'Aberdeen',
#          'Aberdeen City',
#          'AB10 1JS',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d17e941735',
#          'name': 'Indie Movie Theater',
#          'pluralName': 'Indie Movie Theaters',
#          'shortName': 'Indie Movies',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/movietheater_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b69be08f964a5203eb12be3-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51d09643498e476c06365966',
#        'name': 'Six Degrees North',
#        'location': {'address': '6 Littlejohn St',
#         'lat': 57.14997084826783,
#         'lng': -2.096750412799225,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 57.14997084826783,
#           'lng': -2.096750412799225}],
#         'distance': 305,
#         'postalCode': 'AB10 1FF',
#         'cc': 'GB',
#         'city': 'Aberdeen',
#         'state': 'Aberdeen City',
#         'country': 'United Kingdom',
#         'formattedAddress': ['6 Littlejohn St',
#          'Aberdeen',
#          'Aberdeen City',
#          'AB10 1FF',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51d09643498e476c06365966-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '515ee780e4b0236355753398',
#        'name': 'CUP',
#        'location': {'address': '9 Little Belmont Street',
#         'lat': 57.14688471032573,
#         'lng': -2.1007384063853616,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 57.14688471032573,
#           'lng': -2.1007384063853616}],
#         'distance': 502,
#         'cc': 'GB',
#         'city': 'Aberdeen',
#         'state': 'Aberdeen City',
#         'country': 'United Kingdom',
#         'formattedAddress': ['9 Little Belmont Street',
#          'Aberdeen',
#          'Aberdeen City',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d1dc931735',
#          'name': 'Tea Room',
#          'pluralName': 'Tea Rooms',
#          'shortName': 'Tea Room',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/tearoom_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-515ee780e4b0236355753398-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b5f5543f964a5208eb429e3',
#        'name': 'The Grill',
#        'location': {'address': '213 Union St',
#         'lat': 57.14493076031537,
#         'lng': -2.104434432972866,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 57.14493076031537,
#           'lng': -2.104434432972866}],
#         'distance': 792,
#         'postalCode': 'AB11 6BA',
#         'cc': 'GB',
#         'city': 'Aberdeen',
#         'state': 'Aberdeen City',
#         'country': 'United Kingdom',
#         'formattedAddress': ['213 Union St',
#          'Aberdeen',
#          'Aberdeen City',
#          'AB11 6BA',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d122941735',
#          'name': 'Whisky Bar',
#          'pluralName': 'Whisky Bars',
#          'shortName': 'Whisky Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/whiskey_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b5f5543f964a5208eb429e3-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5beb5902dd70c552d2a65a25',
#        'name': 'BrewDog Union Square',
#        'location': {'address': 'Union Square',
#         'crossStreet': 'Guild St',
#         'lat': 57.14369815648724,
#         'lng': -2.097280230539253,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 57.14369815648724,
#           'lng': -2.097280230539253}],
#         'distance': 573,
#         'postalCode': 'AB11 5RG',
#         'cc': 'GB',
#         'city': 'Aberdeen',
#         'state': 'Aberdeen City',
#         'country': 'United Kingdom',
#         'formattedAddress': ['Union Square (Guild St)',
#          'Aberdeen',
#          'Aberdeen City',
#          'AB11 5RG',
#          'United Kingdom']},
#        'categories': [{'id': '56aa371ce4b08b9a8d57356c',
#          'name': 'Beer Bar',
#          'pluralName': 'Beer Bars',
#          'shortName': 'Beer Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5beb5902dd70c552d2a65a25-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b8984ecf964a520463e32e3',
#        'name': 'Bistro Verde',
#        'location': {'address': 'Units 1-2, The Green',
#         'lat': 57.14592574442541,
#         'lng': -2.0992684364318848,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 57.14592574442541,
#           'lng': -2.0992684364318848}],
#         'distance': 467,
#         'postalCode': 'AB11 6NY',
#         'cc': 'GB',
#         'city': 'Aberdeen',
#         'state': 'Aberdeen City',
#         'country': 'United Kingdom',
#         'formattedAddress': ['Units 1-2, The Green',
#          'Aberdeen',
#          'Aberdeen City',
#          'AB11 6NY',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d1ce941735',
#          'name': 'Seafood Restaurant',
#          'pluralName': 'Seafood Restaurants',
#          'shortName': 'Seafood',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b8984ecf964a520463e32e3-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bc05bccf8219c745776b110',
#        'name': 'Waterstones',
#        'location': {'address': '3-7 Union Bridge, Trinity Centre',
#         'lat': 57.14551252785021,
#         'lng': -2.10103399461863,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 57.14551252785021,
#           'lng': -2.10103399461863}],
#         'distance': 582,
#         'postalCode': 'AB11 6BG',
#         'cc': 'GB',
#         'city': 'Aberdeen',
#         'state': 'Aberdeen City',
#         'country': 'United Kingdom',
#         'formattedAddress': ['3-7 Union Bridge, Trinity Centre',
#          'Aberdeen',
#          'Aberdeen City',
#          'AB11 6BG',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d114951735',
#          'name': 'Bookstore',
#          'pluralName': 'Bookstores',
#          'shortName': 'Bookstore',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bookstore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bc05bccf8219c745776b110-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5aa656fc2b984454b87ee8b5',
#        'name': 'Fierce Bar Aberdeen',
#        'location': {'address': '4-6 Exchequer Row',
#         'lat': 57.14738886895232,
#         'lng': -2.094415048804954,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 57.14738886895232,
#           'lng': -2.094415048804954}],
#         'distance': 135,
#         'postalCode': 'AB11 5BW',
#         'cc': 'GB',
#         'city': 'Aberdeen',
#         'state': 'Aberdeen City',
#         'country': 'United Kingdom',
#         'formattedAddress': ['4-6 Exchequer Row',
#          'Aberdeen',
#          'Aberdeen City',
#          'AB11 5BW',
#          'United Kingdom']},
#        'categories': [{'id': '56aa371ce4b08b9a8d57356c',
#          'name': 'Beer Bar',
#          'pluralName': 'Beer Bars',
#          'shortName': 'Beer Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5aa656fc2b984454b87ee8b5-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bc08c3c2a89ef3b17a4f088',
#        'name': 'Fusion Bar and Bistro',
#        'location': {'address': '10 North Silver Street',
#         'lat': 57.146668,
#         'lng': -2.105618,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 57.146668,
#           'lng': -2.105618}],
#         'distance': 793,
#         'postalCode': 'AB10 1RL',
#         'cc': 'GB',
#         'city': 'Aberdeen',
#         'state': 'Aberdeen City',
#         'country': 'United Kingdom',
#         'formattedAddress': ['10 North Silver Street',
#          'Aberdeen',
#          'Aberdeen City',
#          'AB10 1RL',
#          'United Kingdom']},
#        'categories': [{'id': '52e81612bcbc57f1066b79f9',
#          'name': 'Modern European Restaurant',
#          'pluralName': 'Modern European Restaurants',
#          'shortName': 'Modern European',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bc08c3c2a89ef3b17a4f088-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d84c1d07e8ef04dc09411be',
#        'name': 'Aberdeen Beach',
#        'location': {'address': 'Beach Esplanade, Sea Beach',
#         'lat': 57.15137695408196,
#         'lng': -2.0785629283025635,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 57.15137695408196,
#           'lng': -2.0785629283025635}],
#         'distance': 928,
#         'postalCode': 'AB24 5NS',
#         'cc': 'GB',
#         'city': 'Aberdeenshire',
#         'state': 'Aberdeenshire',
#         'country': 'United Kingdom',
#         'formattedAddress': ['Beach Esplanade, Sea Beach',
#          'Aberdeenshire',
#          'AB24 5NS',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d1e2941735',
#          'name': 'Beach',
#          'pluralName': 'Beaches',
#          'shortName': 'Beach',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/beach_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d84c1d07e8ef04dc09411be-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b7bfc5ff964a5201e772fe3',
#        'name': 'Apple Union Square',
#        'location': {'address': '27/28 Ground Level Mall, Union Square',
#         'lat': 57.143341,
#         'lng': -2.096288,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 57.143341,
#           'lng': -2.096288}],
#         'distance': 584,
#         'postalCode': 'AB11 5PN',
#         'cc': 'GB',
#         'city': 'Aberdeen',
#         'state': 'Aberdeen City',
#         'country': 'United Kingdom',
#         'formattedAddress': ['27/28 Ground Level Mall, Union Square',
#          'Aberdeen',
#          'Aberdeen City',
#          'AB11 5PN',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d122951735',
#          'name': 'Electronics Store',
#          'pluralName': 'Electronics Stores',
#          'shortName': 'Electronics',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/technology_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b7bfc5ff964a5201e772fe3-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53a9e1ff498ef91b3d18c28c',
#        'name': 'The Foodstory Café',
#        'location': {'address': '15 Thistle Street',
#         'lat': 57.144030801650715,
#         'lng': -2.110887858346506,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 57.144030801650715,
#           'lng': -2.110887858346506}],
#         'distance': 1188,
#         'postalCode': 'AB10 1XZ',
#         'cc': 'GB',
#         'city': 'Aberdeen',
#         'state': 'Aberdeen City',
#         'country': 'United Kingdom',
#         'formattedAddress': ['15 Thistle Street',
#          'Aberdeen',
#          'Aberdeen City',
#          'AB10 1XZ',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '88934971'}},
#       'referralId': 'e-0-53a9e1ff498ef91b3d18c28c-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b76cae2f964a5207c5f2ee3',
#        'name': "His Majesty's Theatre",
#        'location': {'address': 'Rosemount Viaduct',
#         'lat': 57.14801842443878,
#         'lng': -2.1048527978193654,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 57.14801842443878,
#           'lng': -2.1048527978193654}],
#         'distance': 727,
#         'postalCode': 'AB25 1GL',
#         'cc': 'GB',
#         'city': 'Aberdeen',
#         'state': 'Aberdeen City',
#         'country': 'United Kingdom',
#         'formattedAddress': ['Rosemount Viaduct',
#          'Aberdeen',
#          'Aberdeen City',
#          'AB25 1GL',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d137941735',
#          'name': 'Theater',
#          'pluralName': 'Theaters',
#          'shortName': 'Theater',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_theater_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b76cae2f964a5207c5f2ee3-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b53506ff964a520e19627e3',
#        'name': 'The Jewel In The Crown',
#        'location': {'address': '145 Crown St.',
#         'crossStreet': 'Affleck St.',
#         'lat': 57.14134828507425,
#         'lng': -2.1010332445395785,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 57.14134828507425,
#           'lng': -2.1010332445395785}],
#         'distance': 914,
#         'postalCode': 'AB11 6HP',
#         'cc': 'GB',
#         'city': 'Aberdeenshire',
#         'state': 'Aberdeenshire',
#         'country': 'United Kingdom',
#         'formattedAddress': ['145 Crown St. (Affleck St.)',
#          'Aberdeenshire',
#          'AB11 6HP',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d10f941735',
#          'name': 'Indian Restaurant',
#          'pluralName': 'Indian Restaurants',
#          'shortName': 'Indian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b53506ff964a520e19627e3-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5c825afc35f983002cbf4fcb',
#        'name': 'THE HOP & ANCHOR',
#        'location': {'address': '33 Exchange Street',
#         'lat': 57.145456,
#         'lng': -2.096575,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 57.145456,
#           'lng': -2.096575}],
#         'distance': 384,
#         'postalCode': 'AB11 6PH',
#         'cc': 'GB',
#         'city': 'Aberdeen',
#         'state': 'Aberdeen City',
#         'country': 'United Kingdom',
#         'formattedAddress': ['33 Exchange Street',
#          'Aberdeen',
#          'Aberdeen City',
#          'AB11 6PH',
#          'United Kingdom']},
#        'categories': [{'id': '56aa371ce4b08b9a8d57356c',
#          'name': 'Beer Bar',
#          'pluralName': 'Beer Bars',
#          'shortName': 'Beer Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5c825afc35f983002cbf4fcb-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b4ada8ff964a520178f26e3',
#        'name': 'Books and Beans',
#        'location': {'address': '22 Belmont Street',
#         'lat': 57.146853962047075,
#         'lng': -2.1014362831553877,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 57.146853962047075,
#           'lng': -2.1014362831553877}],
#         'distance': 543,
#         'postalCode': 'AB10 1JH',
#         'cc': 'GB',
#         'city': 'Aberdeen',
#         'state': 'Aberdeen City',
#         'country': 'United Kingdom',
#         'formattedAddress': ['22 Belmont Street',
#          'Aberdeen',
#          'Aberdeen City',
#          'AB10 1JH',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b4ada8ff964a520178f26e3-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b0991f4f964a5209f1923e3',
#        'name': 'Ninety-Nine Bar & Kitchen',
#        'location': {'address': '1 Back Wynd',
#         'lat': 57.146432658095996,
#         'lng': -2.099674177173315,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 57.146432658095996,
#           'lng': -2.099674177173315}],
#         'distance': 460,
#         'postalCode': 'AB10 1JN',
#         'cc': 'GB',
#         'neighborhood': 'City Centre',
#         'city': 'Aberdeen',
#         'state': 'Aberdeen City',
#         'country': 'United Kingdom',
#         'formattedAddress': ['1 Back Wynd',
#          'Aberdeen',
#          'Aberdeen City',
#          'AB10 1JN',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b0991f4f964a5209f1923e3-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b9fce8df964a520754037e3',
#        'name': 'Yatai',
#        'location': {'address': '53 Langstane place',
#         'lat': 57.14312470318974,
#         'lng': -2.107582565315408,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 57.14312470318974,
#           'lng': -2.107582565315408}],
#         'distance': 1058,
#         'postalCode': 'AB11 6EN',
#         'cc': 'GB',
#         'city': 'Aberdeen',
#         'state': 'Aberdeen City',
#         'country': 'United Kingdom',
#         'formattedAddress': ['53 Langstane place',
#          'Aberdeen',
#          'Aberdeen City',
#          'AB11 6EN',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d111941735',
#          'name': 'Japanese Restaurant',
#          'pluralName': 'Japanese Restaurants',
#          'shortName': 'Japanese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b9fce8df964a520754037e3-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c5bce3094fd0f47e0eec645',
#        'name': 'Linx Ice Arena',
#        'location': {'address': 'Beach Promenade',
#         'lat': 57.15662405478564,
#         'lng': -2.080766849201362,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 57.15662405478564,
#           'lng': -2.080766849201362}],
#         'distance': 1182,
#         'postalCode': 'AB24 5NR',
#         'cc': 'GB',
#         'city': 'Aberdeen',
#         'state': 'Aberdeen City',
#         'country': 'United Kingdom',
#         'formattedAddress': ['Beach Promenade',
#          'Aberdeen',
#          'Aberdeen City',
#          'AB24 5NR',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d168941735',
#          'name': 'Skating Rink',
#          'pluralName': 'Skating Rinks',
#          'shortName': 'Skating Rink',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/skatingrink_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c5bce3094fd0f47e0eec645-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bf7a5c3b182c9b69415765a',
#        'name': 'The Coffee House',
#        'location': {'address': '1 Gaelic Lane',
#         'lat': 57.14644432142638,
#         'lng': -2.100663852957198,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 57.14644432142638,
#           'lng': -2.100663852957198}],
#         'distance': 514,
#         'postalCode': 'AB10 1JF',
#         'cc': 'GB',
#         'city': 'Aberdeen',
#         'state': 'Aberdeen City',
#         'country': 'United Kingdom',
#         'formattedAddress': ['1 Gaelic Lane',
#          'Aberdeen',
#          'Aberdeen City',
#          'AB10 1JF',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bf7a5c3b182c9b69415765a-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c782d9497028cfabbecd6fe',
#        'name': 'Moonfish Cafe',
#        'location': {'address': '9 Correction Wynd',
#         'lat': 57.147133243217915,
#         'lng': -2.099108712948141,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 57.147133243217915,
#           'lng': -2.099108712948141}],
#         'distance': 399,
#         'postalCode': 'AB10 1HP',
#         'cc': 'GB',
#         'city': 'Aberdeen',
#         'state': 'Aberdeen City',
#         'country': 'United Kingdom',
#         'formattedAddress': ['9 Correction Wynd',
#          'Aberdeen',
#          'Aberdeen City',
#          'AB10 1HP',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d1ce941735',
#          'name': 'Seafood Restaurant',
#          'pluralName': 'Seafood Restaurants',
#          'shortName': 'Seafood',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c782d9497028cfabbecd6fe-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '595e7459b1ec13252992f766',
#        'name': 'The Craftsman Company',
#        'location': {'address': '2 Guild Street',
#         'lat': 57.14538797387523,
#         'lng': -2.0958472850208594,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 57.14538797387523,
#           'lng': -2.0958472850208594}],
#         'distance': 366,
#         'postalCode': 'AB11 6NE',
#         'cc': 'GB',
#         'city': 'Aberdeen',
#         'state': 'Aberdeen City',
#         'country': 'United Kingdom',
#         'formattedAddress': ['2 Guild Street',
#          'Aberdeen',
#          'Aberdeen City',
#          'AB11 6NE',
#          'United Kingdom']},
#        'categories': [{'id': '56aa371ce4b08b9a8d57356c',
#          'name': 'Beer Bar',
#          'pluralName': 'Beer Bars',
#          'shortName': 'Beer Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-595e7459b1ec13252992f766-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b48a7e8f964a520ca5126e3',
#        'name': 'Kilau Coffee',
#        'location': {'address': '57/59 High St',
#         'lat': 57.16566423437108,
#         'lng': -2.1021869493365184,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 57.16566423437108,
#           'lng': -2.1021869493365184}],
#         'distance': 2020,
#         'postalCode': 'AB24 3EH',
#         'cc': 'GB',
#         'city': 'Aberdeen',
#         'state': 'Aberdeen City',
#         'country': 'United Kingdom',
#         'formattedAddress': ['57/59 High St',
#          'Aberdeen',
#          'Aberdeen City',
#          'AB24 3EH',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b48a7e8f964a520ca5126e3-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cee59c84cd4236a864bad63',
#        'name': 'Grosvenor Casino',
#        'location': {'address': '5 Exchequer Row',
#         'lat': 57.14737200937696,
#         'lng': -2.0940611844681567,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 57.14737200937696,
#           'lng': -2.0940611844681567}],
#         'distance': 122,
#         'postalCode': 'AB11 5BW',
#         'cc': 'GB',
#         'city': 'Aberdeen',
#         'country': 'United Kingdom',
#         'formattedAddress': ['5 Exchequer Row',
#          'Aberdeen',
#          'AB11 5BW',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d17c941735',
#          'name': 'Casino',
#          'pluralName': 'Casinos',
#          'shortName': 'Casino',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/casino_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cee59c84cd4236a864bad63-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bb77ec9b35776b042a8c701',
#        'name': 'Mi Amore',
#        'location': {'address': 'Huntly street',
#         'lat': 57.14604365127101,
#         'lng': -2.1098199019687454,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 57.14604365127101,
#           'lng': -2.1098199019687454}],
#         'distance': 1056,
#         'cc': 'GB',
#         'city': 'Aberdeen',
#         'state': 'Aberdeen City',
#         'country': 'United Kingdom',
#         'formattedAddress': ['Huntly street',
#          'Aberdeen',
#          'Aberdeen City',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bb77ec9b35776b042a8c701-29'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4baf4748f964a52032f53be3',
#        'name': 'The Sanddollar Café',
#        'location': {'address': '2 Beach Esplanade',
#         'lat': 57.15166772532892,
#         'lng': -2.0781637892466,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 57.15166772532892,
#           'lng': -2.0781637892466}],
#         'distance': 963,
#         'postalCode': 'AB24 5NS',
#         'cc': 'GB',
#         'city': 'Aberdeen',
#         'state': 'Aberdeen City',
#         'country': 'United Kingdom',
#         'formattedAddress': ['2 Beach Esplanade',
#          'Aberdeen',
#          'Aberdeen City',
#          'AB24 5NS',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4baf4748f964a52032f53be3-30'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bb0608df964a5201d433ce3',
#        'name': 'The Lemon Tree',
#        'location': {'address': '5 West North Street',
#         'lat': 57.1499495004574,
#         'lng': -2.0947997510972414,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 57.1499495004574,
#           'lng': -2.0947997510972414}],
#         'distance': 224,
#         'postalCode': 'AB24 5AT',
#         'cc': 'GB',
#         'city': 'Aberdeen',
#         'state': 'Aberdeen City',
#         'country': 'United Kingdom',
#         'formattedAddress': ['5 West North Street',
#          'Aberdeen',
#          'Aberdeen City',
#          'AB24 5AT',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d1f2931735',
#          'name': 'Performing Arts Venue',
#          'pluralName': 'Performing Arts Venues',
#          'shortName': 'Performing Arts',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bb0608df964a5201d433ce3-31'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ca78943f47ea14360cf6b21',
#        'name': 'No. 1 Bar/Grill',
#        'location': {'address': '1 Queens Terrace',
#         'lat': 57.14328552659155,
#         'lng': -2.119574172730756,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 57.14328552659155,
#           'lng': -2.119574172730756}],
#         'distance': 1707,
#         'postalCode': 'AB10 1XL',
#         'cc': 'GB',
#         'city': 'Aberdeen',
#         'country': 'United Kingdom',
#         'formattedAddress': ['1 Queens Terrace',
#          'Aberdeen',
#          'AB10 1XL',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ca78943f47ea14360cf6b21-32'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b533416f964a5202e9227e3',
#        'name': 'Duthie Park',
#        'location': {'address': 'Great Southern Road',
#         'lat': 57.129695636918235,
#         'lng': -2.1069946410500315,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 57.129695636918235,
#           'lng': -2.1069946410500315}],
#         'distance': 2235,
#         'cc': 'GB',
#         'city': 'Aberdeen',
#         'state': 'Aberdeen City',
#         'country': 'United Kingdom',
#         'formattedAddress': ['Great Southern Road',
#          'Aberdeen',
#          'Aberdeen City',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'shortName': 'Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b533416f964a5202e9227e3-33'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c82c42ad4e2370439086b88',
#        'name': 'No 10 Tavern',
#        'location': {'address': "10 Queen's Terrace",
#         'lat': 57.14340948306346,
#         'lng': -2.1212212413979668,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 57.14340948306346,
#           'lng': -2.1212212413979668}],
#         'distance': 1798,
#         'postalCode': 'AB10 1XL',
#         'cc': 'GB',
#         'city': 'Aberdeen',
#         'state': 'Aberdeen City',
#         'country': 'United Kingdom',
#         'formattedAddress': ["10 Queen's Terrace",
#          'Aberdeen',
#          'Aberdeen City',
#          'AB10 1XL',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c82c42ad4e2370439086b88-34'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bf5f6315e800f47e7a6e6d4',
#        'name': "O'Neill's",
#        'location': {'address': '9-10 Back Wynd',
#         'lat': 57.14678651102132,
#         'lng': -2.0999291259919954,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 57.14678651102132,
#           'lng': -2.0999291259919954}],
#         'distance': 459,
#         'postalCode': 'AB10 1JN',
#         'cc': 'GB',
#         'city': 'Aberdeen',
#         'state': 'Aberdeen City',
#         'country': 'United Kingdom',
#         'formattedAddress': ['9-10 Back Wynd',
#          'Aberdeen',
#          'Aberdeen City',
#          'AB10 1JN',
#          'United Kingdom']},
#        'categories': [{'id': '52e81612bcbc57f1066b7a06',
#          'name': 'Irish Pub',
#          'pluralName': 'Irish Pubs',
#          'shortName': 'Irish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bf5f6315e800f47e7a6e6d4-35'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b59d939f964a520b59b28e3',
#        'name': 'Ferryhill Hotel',
#        'location': {'address': 'Bon Accord St',
#         'lat': 57.13791218689612,
#         'lng': -2.104593315347444,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 57.13791218689612,
#           'lng': -2.104593315347444}],
#         'distance': 1352,
#         'postalCode': 'AB11 6UA',
#         'cc': 'GB',
#         'city': 'Aberdeen',
#         'state': 'Aberdeen City',
#         'country': 'United Kingdom',
#         'formattedAddress': ['Bon Accord St',
#          'Aberdeen',
#          'Aberdeen City',
#          'AB11 6UA',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b59d939f964a520b59b28e3-36'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '55f85590498ef6abbc5e2e67',
#        'name': 'Aldi',
#        'location': {'lat': 57.14869356384922,
#         'lng': -2.081519166165332,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 57.14869356384922,
#           'lng': -2.081519166165332}],
#         'distance': 683,
#         'cc': 'GB',
#         'country': 'United Kingdom',
#         'formattedAddress': ['United Kingdom']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#          'name': 'Supermarket',
#          'pluralName': 'Supermarkets',
#          'shortName': 'Supermarket',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-55f85590498ef6abbc5e2e67-37'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c2104c34889a59305512720',
#        'name': 'Silver Darling',
#        'location': {'address': 'North Pier, Pocra Quay',
#         'lat': 57.14247748528645,
#         'lng': -2.069445426585876,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 57.14247748528645,
#           'lng': -2.069445426585876}],
#         'distance': 1550,
#         'postalCode': 'AB11 5DQ',
#         'cc': 'GB',
#         'city': 'Aberdeen',
#         'state': 'Aberdeen City',
#         'country': 'United Kingdom',
#         'formattedAddress': ['North Pier, Pocra Quay',
#          'Aberdeen',
#          'Aberdeen City',
#          'AB11 5DQ',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d1ce941735',
#          'name': 'Seafood Restaurant',
#          'pluralName': 'Seafood Restaurants',
#          'shortName': 'Seafood',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '150835185'}},
#       'referralId': 'e-0-4c2104c34889a59305512720-38'},
#      {'reasons': {'count': 0,
# ...
#         'formattedAddress': ['10 Cornhill Shopping Arcade',
#          'Aberdeen',
#          'Aberdeen City',
#          'AB16 5UT',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d118951735',
#          'name': 'Grocery Store',
#          'pluralName': 'Grocery Stores',
#          'shortName': 'Grocery Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d31d099329e54819c57aa1d-86'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '504f657b7e27022f969b6581',
#        'name': 'Co-op Food',
#        'location': {'address': '76/78 Countesswells Rd',
#         'lat': 57.13317255731828,
#         'lng': -2.14756238865332,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 57.13317255731828,
#           'lng': -2.14756238865332}],
#         'distance': 3708,
#         'postalCode': 'AB15 7YJ',
#         'cc': 'GB',
#         'city': 'Aberdeenshire',
#         'state': 'Aberdeenshire',
#         'country': 'United Kingdom',
#         'formattedAddress': ['76/78 Countesswells Rd',
#          'Aberdeenshire',
#          'AB15 7YJ',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d118951735',
#          'name': 'Grocery Store',
#          'pluralName': 'Grocery Stores',
#          'shortName': 'Grocery Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-504f657b7e27022f969b6581-87'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cd142a96200b1f752b6d828',
#        'name': 'Sterling Homestore',
#        'location': {'address': '40 Denmore Rd',
#         'crossStreet': 'Bridge of Don',
#         'lat': 57.19090775578696,
#         'lng': -2.0912568322564415,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 57.19090775578696,
#           'lng': -2.0912568322564415}],
#         'distance': 4750,
#         'postalCode': 'AB23 8JW',
#         'cc': 'GB',
#         'city': 'Aberdeen City',
#         'state': 'Aberdeen City',
#         'country': 'United Kingdom',
#         'formattedAddress': ['40 Denmore Rd (Bridge of Don)',
#          'Aberdeen City',
#          'AB23 8JW',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d1f8941735',
#          'name': 'Furniture / Home Store',
#          'pluralName': 'Furniture / Home Stores',
#          'shortName': 'Furniture / Home',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/furniture_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cd142a96200b1f752b6d828-88'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4fd24d94e4b069289203c39c',
#        'name': 'Co-op Food',
#        'location': {'address': 'Sclattie Park Shopping Centre, Bucksbarn',
#         'lat': 57.18014244125572,
#         'lng': -2.1870302646718933,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 57.18014244125572,
#           'lng': -2.1870302646718933}],
#         'distance': 6704,
#         'postalCode': 'AB21 9QL',
#         'cc': 'GB',
#         'city': 'Aberdeenshire',
#         'state': 'Aberdeenshire',
#         'country': 'United Kingdom',
#         'formattedAddress': ['Sclattie Park Shopping Centre, Bucksbarn',
#          'Aberdeenshire',
#          'AB21 9QL',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d118951735',
#          'name': 'Grocery Store',
#          'pluralName': 'Grocery Stores',
#          'shortName': 'Grocery Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4fd24d94e4b069289203c39c-89'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51a38c8d498e848204236509',
#        'name': 'Lidl',
#        'location': {'address': 'Inverurie Road',
#         'lat': 57.179334658508,
#         'lng': -2.17610505009117,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 57.179334658508,
#           'lng': -2.17610505009117}],
#         'distance': 6103,
#         'postalCode': 'AB21 9LZ',
#         'cc': 'GB',
#         'city': 'Aberdeen',
#         'state': 'Aberdeen City',
#         'country': 'United Kingdom',
#         'formattedAddress': ['Inverurie Road',
#          'Aberdeen',
#          'Aberdeen City',
#          'AB21 9LZ',
#          'United Kingdom']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#          'name': 'Supermarket',
#          'pluralName': 'Supermarkets',
#          'shortName': 'Supermarket',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '547150677'}},
#       'referralId': 'e-0-51a38c8d498e848204236509-90'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51274519e4b02d0004b98d5f',
#        'name': 'Costa Coffee',
#        'location': {'address': 'Garthdee Campus',
#         'lat': 57.12007436263505,
#         'lng': -2.1358259386440395,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 57.12007436263505,
#           'lng': -2.1358259386440395}],
#         'distance': 4072,
#         'cc': 'GB',
#         'country': 'United Kingdom',
#         'formattedAddress': ['Garthdee Campus', 'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51274519e4b02d0004b98d5f-91'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ca720f414c337040e3cc63b',
#        'name': 'Iceland',
#        'location': {'address': '461-475 Great Northern Rd',
#         'lat': 57.17212342563808,
#         'lng': -2.1279291459761285,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 57.17212342563808,
#           'lng': -2.1279291459761285}],
#         'distance': 3400,
#         'postalCode': 'AB24 2BD',
#         'cc': 'GB',
#         'city': 'Aberdeen',
#         'state': 'Aberdeen City',
#         'country': 'United Kingdom',
#         'formattedAddress': ['461-475 Great Northern Rd',
#          'Aberdeen',
#          'Aberdeen City',
#          'AB24 2BD',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d118951735',
#          'name': 'Grocery Store',
#          'pluralName': 'Grocery Stores',
#          'shortName': 'Grocery Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ca720f414c337040e3cc63b-92'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5a4e45094b78c52e9f4db035',
#        'name': 'Home Bargains',
#        'location': {'address': 'Denmore Rd',
#         'lat': 57.20169707,
#         'lng': -2.09142722,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 57.20169707,
#           'lng': -2.09142722}],
#         'distance': 5951,
#         'postalCode': 'AB23 8JW',
#         'cc': 'GB',
#         'city': 'Aberdeen',
#         'state': 'Aberdeen City',
#         'country': 'United Kingdom',
#         'formattedAddress': ['Denmore Rd',
#          'Aberdeen',
#          'Aberdeen City',
#          'AB23 8JW',
#          'United Kingdom']},
#        'categories': [{'id': '52dea92d3cf9994f4e043dbb',
#          'name': 'Discount Store',
#          'pluralName': 'Discount Stores',
#          'shortName': 'Discount Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/discountstore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '587493825'}},
#       'referralId': 'e-0-5a4e45094b78c52e9f4db035-93'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c7d060309b29c74713fe63c',
#        'name': 'Mill of Mundurno',
#        'location': {'address': 'Murcar',
#         'lat': 57.2035162,
#         'lng': -2.0895687,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 57.2035162,
#           'lng': -2.0895687}],
#         'distance': 6156,
#         'postalCode': 'AB23 8BP',
#         'cc': 'GB',
#         'city': 'Bridge of Don',
#         'state': 'Aberdeen City',
#         'country': 'United Kingdom',
#         'formattedAddress': ['Murcar',
#          'Bridge of Don',
#          'Aberdeen City',
#          'AB23 8BP',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c7d060309b29c74713fe63c-94'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4fce80a10e1d45263ee10739',
#        'name': 'Holiday Inn Express Aberdeen Exhibition Centre',
#        'location': {'address': 'Parkway East, Bridge of Don',
#         'lat': 57.1863258,
#         'lng': -2.0873531,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 57.1863258,
#           'lng': -2.0873531}],
#         'distance': 4252,
#         'postalCode': 'AB23 8AJ',
#         'cc': 'GB',
#         'city': 'Aberdeen',
#         'state': 'Aberdeen City',
#         'country': 'United Kingdom',
#         'formattedAddress': ['Parkway East, Bridge of Don',
#          'Aberdeen',
#          'Aberdeen City',
#          'AB23 8AJ',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4fce80a10e1d45263ee10739-95'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '58bc3767d8f3e95ec256ba6f',
#        'name': 'M&S Foodhall',
#        'location': {'address': 'Beech Manor',
#         'lat': 57.18850212,
#         'lng': -2.17819353,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 57.18850212,
#           'lng': -2.17819353}],
#         'distance': 6829,
#         'postalCode': 'AB21 9AZ',
#         'cc': 'GB',
#         'city': 'Aberdeen',
#         'state': 'Aberdeen City',
#         'country': 'United Kingdom',
#         'formattedAddress': ['Beech Manor',
#          'Aberdeen',
#          'Aberdeen City',
#          'AB21 9AZ',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d118951735',
#          'name': 'Grocery Store',
#          'pluralName': 'Grocery Stores',
#          'shortName': 'Grocery Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '568860076'}},
#       'referralId': 'e-0-58bc3767d8f3e95ec256ba6f-96'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50af8f17e4b0b42d0e835d08',
#        'name': 'Costa Coffee',
#        'location': {'lat': 57.118092,
#         'lng': -2.174583,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 57.118092,
#           'lng': -2.174583}],
#         'distance': 5972,
#         'cc': 'GB',
#         'country': 'United Kingdom',
#         'formattedAddress': ['United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50af8f17e4b0b42d0e835d08-97'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4de66fe5fa764cf4bedf4766',
#        'name': 'Mains Of Scotstown Inn',
#        'location': {'lat': 57.188486,
#         'lng': -2.119642496109009,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 57.188486,
#           'lng': -2.119642496109009}],
#         'distance': 4763,
#         'cc': 'GB',
#         'country': 'United Kingdom',
#         'formattedAddress': ['United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4de66fe5fa764cf4bedf4766-98'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5b657a62f5e9d7002c8c66af',
#        'name': 'M&S Simply Food',
#        'location': {'address': 'Denmore Road',
#         'lat': 57.2017283,
#         'lng': -2.09150589,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 57.2017283,
#           'lng': -2.09150589}],
#         'distance': 5954,
#         'postalCode': 'AB23 8JW',
#         'cc': 'GB',
#         'city': 'Aberdeen',
#         'state': 'Aberdeen City',
#         'country': 'United Kingdom',
#         'formattedAddress': ['Denmore Road',
#          'Aberdeen',
#          'Aberdeen City',
#          'AB23 8JW',
#          'United Kingdom']},
#        'categories': [{'id': '4bf58dd8d48988d118951735',
#          'name': 'Grocery Store',
#          'pluralName': 'Grocery Stores',
#          'shortName': 'Grocery Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '569857260'}},
#       'referralId': 'e-0-5b657a62f5e9d7002c8c66af-99'}]}]}}

# %%
venues = results['response']['groups'][0]['items']
    
ab_venues = pd.json_normalize(venues) # flatten JSON

# filtering the columns
filtered_columns = ['venue.name', 'venue.location.postalCode','venue.location.lat', 'venue.location.lng']
ab_venues =ab_venues.loc[:, filtered_columns]

# cleaning the columns
ab_venues.columns = [col.split(".")[-1] for col in ab_venues.columns]

#renaming the columns
ab_venues=ab_venues.rename(columns={'lat':'Latitude','lng':'Longitutde','name':'Venue_name','postalCode':'PostCode'})

ab_venues.head()
# Out:
#            Venue_name  PostCode   Latitude  Longitutde
# 0  BrewDog Castlegate  AB11 5BU  57.147731   -2.094548
# 1    BrewDog Aberdeen  AB25 1EB  57.149520   -2.097525
# 2       CASC ABERDEEN  AB11 6ND  57.145874   -2.097568
# 3             Cafe 52  AB11 6BE  57.146053   -2.099170
# 4  Revolucion de Cuba  AB10 1LB  57.147413   -2.101209

# %%
print('{} venues were returned by Foursquare.'.format(ab_venues.shape[0]))
# Out:
# 100 venues were returned by Foursquare.

# %%
# creating a map of Aberdeen venues returned from FourSquare
ab_venues_map = folium.Map(location=[latitude, longitude], zoom_start=11)

# adding markers to map
for lat, lng, label in zip(ab_venues['Latitude'], ab_venues['Longitutde'], ab_venues['Venue_name']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(ab_venues_map)  
    
ab_venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_3fdf3023521b4a8e9dc7e7e8875244a9%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_3fdf3023521b4a8e9dc7e7e8875244a9%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_3fdf3023521b4a8e9dc7e7e8875244a9%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_3fdf3023521b4a8e9dc7e7e8875244a9%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B57.1482429%2C%20-2.0928095%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %% [markdown]
# ## Conclusion<a id="5"></a>

# %% [markdown]
# As can be seen when comparing the two maps, the pattern of rental price does not follow the one of venues' frequency. Therefore, proximity to amenities does not impact a rental property's asking price.

# %% [markdown]
# # Thank you for your time.
